# %% [markdown]
# # RDBMS - MySQL
#
# ## 00 - Introduction
#
# Among the Relational DBMSs, the most widely known are Oracle, SQLite, Postgres, MariaDB, and MySQL.
#
# Each one of them is characterized by a different set of "variations" on top of the base SQL language, although usually minor.
#
# We will use **MySQL** to run exercises about Relational DB transactions using the SQL language, as it is *currently* among the top of the list of most widely used RDBMSs.
#
# [DB Engines Ranking Trend](https://db-engines.com/en/ranking_trend/relational+dbms)
#
# [Stack Overflow 2025 Developer Survey - Most Popular Technologies (Language)](https://survey.stackoverflow.co/2025/technology#most-popular-technologies-language)
#
# [Stack Overflow 2025 Developer Survey - Most Popular Technologies (Database)](https://survey.stackoverflow.co/2025/technology#most-popular-technologies-database)

# %% [markdown]
# MySQL programming interfaces exist for many languages, including C, C++, Go, Java, Perl, PHP, Python, etc...
#
# Even simply referring to Python, we can count on several options to connect and interact with the DBs.
#
# Let's explore a couple of them...

# %% [markdown]
# ## 01 - Create a Connection to MySQL
#
# A MySQL server is running within one of your Docker containers.
#
# You can access it using the MySQL server credentials defined in the `docker-compose.yml` file.
#
# By default, a `root` user is created with the following credentials:
# - **Username:** `root`
# - **Password:** `root_pwd`
#
# Additionally, a non-`root` user is created by default with:
# - **Username:** `my_user`
# - **Password:** `my_pwd`

# %% [markdown]
# #### Interactive
#
# To interact with the MySQL server, you can log in interactively to its Docker container.
#
# First, check the `CONTAINER ID` of the container named `mysql_db` by running:
#
# ```bash
# $ docker ps
# ```
#
# Then, initiate an interactive bash session within the container by executing:
#
# ```bash
# $ docker exec -it <YOUR CONTAINER ID> bash
# ```
#
# Once inside the container, you can access the MySQL server as if you were connected to a remote server hosting your databases:
#
# ```bash
# $ mysql -u <EITHER ROOT OR USER> -p
# ```
#
# Replace `<YOUR CONTAINER ID>` with the actual container ID obtained from the `docker ps` command output, and `<EITHER ROOT OR USER>` with either `root` or `my_user`, depending on the user you want to log in as.

# %% [markdown]
# We can then inspect the MySQL server to display all databases by executing the following SQL command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# **NB**: Remember to end a SQL command with a semicolon `;`.

# %% [markdown]
# #### mysql.connector
#
# A more pythonic way to interact with a MySQL server is by using a dedicated driver such as `mysql.connector`, which is already installed in the Jupyter Notebook container.
#
# This connector offers an interface to establish a connection object to the MySQL server and provides various functionalities for executing transactions and fetching records from databases.
#
# We can start by declaring a connection to our MySQL server.
#
# **NB:** The server is hosted in a different container from the notebook, simulating a connection between two different machines: a client and a server.

# %%
# import the connector
import mysql.connector

# declare a connection to the MySQL server 
# the hostname (or IP) of the server machine should be passed
db = mysql.connector.connect(
  user="root",
  password="root_pwd",
  host="db", # in this case 'db' is the equivalent of the IP address of the server 
             # or 'localhost' if running mysql locally
)

print(db)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x7d420ce1e270>

# %% [markdown]
# At this point, a database connection is established.
#
# To interact with the database using Python and `mysql.connector`, we need a "handle" known as a cursor, which must be instantiated.
#
# When using this connector to interact with the database, all SQL statements are executed using the cursor.

# %%
# create our db cursor object
dbc = db.cursor()

# %% [markdown]
# The cursor allows us to execute all SQL transactions on the database as if we were logged into the server.
#
# If a transaction fetches results from the database (returns a set of records), the connector object will retain the results. This feature can be useful for later use in a more "pythonic" way, integrating our database queries with other Python statements.
#
# The syntax for issuing a generic SQL statement is as follows:
#
# ```python
# connector_object.execute(my_sql_query)
# ```
#
# For example, let's execute the same check as before by asking MySQL to show us all available databases...

# %%
# show all available databases
dbc.execute(
"SHOW DATABASES"
)

# %% [markdown]
# No output is printed because the result of this SQL transaction is collected into the cursor as a list of records (tuples).
#
# To retrieve the results, we can simply loop over them.

# %%
# loop over the container to fetch the results
for _ in dbc:
    print(_)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %% [markdown]
# If we are `root` users in this example, we can access the inner structure of the MySQL server, which already contains a few databases by default.
#
# After fetching the output of the transaction, the cursor reaches "the end" of the records and becomes available to perform a new transaction.

# %%
# use fetch to retrieve one, many, or all entries in the cursor
# dbc.fetchone()

dbc.fetchmany(2)

# dbc.fetchall()
# Out:
# []

# %%
dbc.reset()

# %% [markdown]
# If one wants to perform a new transaction without collecting the output of the previous one from the cursor, a reset must be issued first:
#
# ```python
# connector_object.reset()
# ```

# %% [markdown]
# If a generic user (i.e., not the `root` user) is logged into the database server, they will not have access to certain functionalities and won't be able to see the previous list of all databases.
#
# Some of these databases and tables are protected and used to store additional information about the state of the MySQL server and the connected users.

# %%
# connecto to the database as a non-root user
udb = mysql.connector.connect(
  user="my_user",
  password="my_pwd",
  host="db",
)

# create a cursor
udbc = udb.cursor()

# execute the transaction
udbc.execute(
"SHOW DATABASES"
)

# fetch all results
udbc.fetchall()
# Out:
# [('information_schema',), ('performance_schema',)]

# %% [markdown]
# #### iPython Magic
#
# Another way to execute queries from Python within a Jupyter Notebook is by utilizing notebook "magic" functions, which are based on iPython and SQLAlchemy.
#
# This approach is similar to loading inline figures from Matplotlib using `%matplotlib inline`.
#
# To instruct iPython to interpret SQL commands and connect to the appropriate database, we need to:
#
# 1. Load the extension for the SQL language.
# 2. Set the environment variable to point to the connection to the database.

# %%
# %load_ext sql

# %env DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# env: DATABASE_URL=mysql+mysqlconnector://root:root_pwd@db

# %% [markdown]
# Now, notebook cells can execute SQL transactions directly in plain SQL by starting the cell with `%%sql`.
#
# By default, the result is also printed using the `pretty` format, similar to the pandas-like format.

# %%
# %%sql
#
# SHOW DATABASES;
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/connection_cext.py", line 354, in _open_connection
#     self._cmysql.connect(**cnx_kwargs)
#     ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
# _mysql_connector.MySQLInterfaceError: Can't connect to MySQL server on 'db:3306' (111)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/base.py", line 3309, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 447, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 711, in checkout
#     rec = pool._do_get()
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/impl.py", line 177, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/impl.py", line 175, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 388, in _create_connection
#     return _ConnectionRecord(self)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 673, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 899, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 895, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/create.py", line 661, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/default.py", line 630, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/pooling.py", line 322, in connect
#     return CMySQLConnection(*args, **kwargs)
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/connection_cext.py", line 142, in __init__
#     self.connect(**kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/abstracts.py", line 1604, in connect
#     self._open_connection()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/connection_cext.py", line 360, in _open_connection
#     raise get_mysql_exception(
#         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     ) from err
# mysql.connector.errors.DatabaseError: 2003 (HY000): Can't connect to MySQL server on 'db:3306' (111)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.14/site-packages/sql/magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#         connect_str,
#     ...<2 lines>...
#         creator=args.creator,
#     )
#   File "/usr/local/lib/python3.14/site-packages/sql/connection.py", line 78, in set
#     cls.current = Connection(
#                   ~~~~~~~~~~^
#         os.getenv("DATABASE_URL"), connect_args, creator
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.14/site-packages/sql/connection.py", line 55, in __init__
#     self.internal_connection = engine.connect()
#                                ~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/base.py", line 3285, in connect
#     return self._connection_cls(self)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/base.py", line 145, in __init__
#     Connection._handle_dbapi_exception_noconnection(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         err, dialect, engine
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/base.py", line 2448, in _handle_dbapi_exception_noconnection
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/base.py", line 143, in __init__
#     self._dbapi_connection = engine.raw_connection()
#                              ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/base.py", line 3309, in raw_connection
#     return self.pool.connect()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 447, in connect
#     return _ConnectionFairy._checkout(self)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 1264, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 711, in checkout
#     rec = pool._do_get()
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/impl.py", line 177, in _do_get
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/impl.py", line 175, in _do_get
#     return self._create_connection()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 388, in _create_connection
#     return _ConnectionRecord(self)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 673, in __init__
#     self.__connect()
#     ~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 899, in __connect
#     with util.safe_reraise():
#          ~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/util/langhelpers.py", line 224, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/pool/base.py", line 895, in __connect
#     self.dbapi_connection = connection = pool._invoke_creator(self)
#                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/create.py", line 661, in connect
#     return dialect.connect(*cargs, **cparams)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/sqlalchemy/engine/default.py", line 630, in connect
#     return self.loaded_dbapi.connect(*cargs, **cparams)  # type: ignore[no-any-return]  # NOQA: E501
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/pooling.py", line 322, in connect
#     return CMySQLConnection(*args, **kwargs)
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/connection_cext.py", line 142, in __init__
#     self.connect(**kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/abstracts.py", line 1604, in connect
#     self._open_connection()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/local/lib/python3.14/site-packages/mysql/connector/connection_cext.py", line 360, in _open_connection
#     raise get_mysql_exception(
#         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     ) from err
# sqlalchemy.exc.DatabaseError: (mysql.connector.errors.DatabaseError) 2003 (HY000): Can't connect to MySQL server on 'db:3306' (111)
# (Background on this error at: https://sqlalche.me/e/20/4xp6)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# An additional benefit is that a single `%sql` (not a double `%%sql`) can be used to combine a SQL query with any Python command.

# %%
my_python_var = %sql SHOW DATABASES

print(my_python_var)
print(f'First record={my_python_var[0]}')
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# +--------------------+
# |      Database      |
# +--------------------+
# | information_schema |
# |       mysql        |
# | performance_schema |
# |        sys         |
# +--------------------+
# First record=('information_schema',)

# %% [markdown]
# The combination of either of the two Pythonic methods can be used to easily redirect the output of database transactions to leverage other well-known Python modules, such as plotting with Matplotlib.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(my_python_var);
plt.xticks(rotation='vertical');

# %% [markdown]
# ## 02 Database and Table creation

# %% [markdown]
# We have already seen how to inspect the server to see which databases are present using the command:
#
# ```mysql
# SHOW DATABASES;
# ```
#
# To start interacting with a specific database, we can select it using `USE`:
#
# ```mysql
# USE <DB_NAME>;
# ```
#
# If the user has been granted the right to access this database, it's possible to start investigating its content.

# %% [markdown]
# If we want to create a new database to work with instead, we can use the command:
#
# ```mysql
# CREATE DATABASE <DB_NAME>;
# ```
#
# A more complex syntax can be used to create a new database only if no other database with the same name already exists:
#
# ```mysql
# CREATE DATABASE IF NOT EXISTS <DB_NAME>;
# ```

# %% [markdown]
# - Check if a DB named `my_db` exists.
# - If not, create one.
# - Then, switch to the new DB to start using it.

# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS my_db;
# USE my_db;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# All tables contained in the DB are shown in a similar way to what used to show all DBs on the server:
#
# ```mysql
# SHOW TABLES;
# ```
#
# **NB**: we are inspecting the content of a specific DB (the one selected with `USE <DB_NAME>`)

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# The analogous Pythonic way to execute the same list of commands (using the `mysql.connector` driver) is the following:
#
# **NB**: This time we are not retrieving results from the server, but are instead asking the DBMS to _create_ a new database. We are issuing a request that requires us to **commit** a change in the MySQL server

# %%
# defining the sql command line
sql_ = "CREATE DATABASE IF NOT EXISTS my_db;"

# instructing the cursor to execute it
dbc.execute(sql_)

# in this case the result of the sql transaction is not to return a list of items 
# it is instead a change in the DB structure
# therefore, for the change to have an effect, the change is to be committed to the DB
db.commit()

# %% [markdown]
# All other commands discussed so far (`USE` and `SHOW`), do not require any change to be committed, therefore we can simply issue them via the cursor.
#
# Creating new databases, or changing the structure (_schema_) or the content (_instance_) of a database, will instead require a `commit`.

# %%
# use the my_db database
dbc.execute("USE my_db")

# show all tables
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# []

# %% [markdown]
# So far the `my_db` database is empty, so let's use the same lines presented in the slides to create a dummy `Users` table.
#
# Any table can then be inspected to check its schema by listing all attributes.
#
# 1. Begin by creating a `Users` table. Define the schema by specifying each attribute.
# 2. Verify if it has been successfully created in the database. Use the `SHOW` command for this purpose.
# 3. Inspect the schema of the `Users` table, execute the `DESCRIBE <TABLE_NAME>` command.

# %%
# %%sql
#
# # create a table following the schema on the slides
# CREATE TABLE Users (
#     UserID    varchar(30),
#     BadgeNum  int(16),
#     FirstName varchar(255),
#     LastName  varchar(255),
#     Age       int,
#     OtherAttr float
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # show the tables in the current database
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Users',)]

# %%
# %%sql
#
# # describe the table `Users`
# DESCRIBE Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 6 rows affected.
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# Following the previous examples, let's perform the same transactions using the `mysql.connector` driver. Since the `Users` table already exists, we will create a new table called `Users_py`.
#
# Remember the following points:
#
# - Utilize the DB Cursor to execute the transactions.
# - Transactions that change the content of the DB must be _committed_ to the DB.
# - Transactions returning the content of the DB host their results _in the cursor_.

# %%
# create a table following the schema on the slides
sql = 'CREATE TABLE IF NOT EXISTS Users_py (\
       UserID    varchar(30),\
       BadgeNum  int(16),\
       FirstName varchar(255),\
       LastName  varchar(255),\
       Age       int,\
       OtherAttr float);'
dbc.execute(sql)
db.commit()

# %%
# show the tables in the current database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# [('Users',), ('Users_py',)]

# %%
# describe the table `Users_py`
dbc.execute("DESCRIBE Users_py")
dbc.fetchall()
# Out:
# [('UserID', 'varchar(30)', 'YES', '', None, ''),
#  ('BadgeNum', 'int', 'YES', '', None, ''),
#  ('FirstName', 'varchar(255)', 'YES', '', None, ''),
#  ('LastName', 'varchar(255)', 'YES', '', None, ''),
#  ('Age', 'int', 'YES', '', None, ''),
#  ('OtherAttr', 'float', 'YES', '', None, '')]

# %% [markdown]
# ## 03 Declaring constraints and altering tables

# %% [markdown]
# Before moving on, let's clean up all existing tables in our database.
#
# To remove an existing table from the database, you can use the following instruction:
#
# ```mysql
# DROP TABLE IF EXISTS <NAME OF YOUR TABLE>;
# ```
#
# **CAUTION**: Dropping a table deletes all records from that table and severs all connections with other tables based on foreign keys. This action can render the entire database unusable. Be extremely careful when executing this command.

# %%
# %%sql
#
# # drop the table Users
# DROP TABLE IF EXISTS Users;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# Let's also drop the `Users_py` table using the Python connector.
# This is once again an action that alters the database, thus we must `commit` it.

# %%
# drop the table Users_py
dbc.execute("DROP TABLE IF EXISTS Users_py")
db.commit()

# %%
# inspect the content of the database
dbc.execute("SHOW TABLES")
dbc.fetchall()
# Out:
# []

# %% [markdown]
# Create a new `products` table with the following schema:
#
# | Attribute    | Type    | Extra info | Constraint                |
# |--------------|---------|------------|---------------------------|
# | productID    | Integer |            | NOT NULL AUTO_INCREMENT  |
# | productName  | String  | Max length 30 | DEFAULT ''            |
# | unitPrice    | Float   |            | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned   | NOT NULL DEFAULT 0        |
#
#
# The `productID` attribute will be our `PRIMARY KEY`.
#
# This can be declared either inline, or at the end of the table definition:
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY
# ```
#
# or
#
# ```mysql
# productID INT NOT NULL UNIQUE AUTO_INCREMENT
# [...]
# PRIMARY KEY (productID)
# ```

# %%
# %%sql
#
# # create the products table
# CREATE TABLE IF NOT EXISTS products (
#          productID    INT          NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#          productName  VARCHAR(30)  DEFAULT '' ,
#          unitPrice    FLOAT        NOT NULL DEFAULT 99999.99,
#          unitsInStock INT UNSIGNED NOT NULL DEFAULT 0
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', '')]

# %% [markdown]
# The table does not contain any constraints, default values, or foreign keys.
#
# The **schema** of a given table can be altered by adding/removing Attributes, as well as by adding constraints.
#
# Let's first add a new attribute to the table:
#
# | Attribute       | Type    | Extra info     | Constraint                |
# |-----------------|---------|----------------|---------------------------|
# | productID       | Integer |                | NOT NULL AUTO_INCREMENT  |
# | productName     | String  | Max length 30  | DEFAULT ''               |
# | unitPrice       | Float   |                | NOT NULL DEFAULT 99999.99|
# | unitsInStock    | Integer | Unsigned       | NOT NULL DEFAULT 0       |
# | **isDiscontinued** | **Bool** |              | NOT NULL                  |
#
#
# To alter the **schema** of a table and create a new column we can act on it with:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ADD COLUMN <NEW COL> <THE NEW ATTRIBUTE DECLARATION>;
# ```

# %% [markdown]
# #### Alter the `products` table and add the `isDiscontinued` attribute

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ADD COLUMN isDiscontinued BOOL NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', None, '')]

# %% [markdown]
# The `isDiscontinued` attribute does not contain any meaningful constraint or default value.
# Let's consider `0` as a good default value for this attribute:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL **DEFAULT 0** |
#
# We can use the same `ALTER TABLE` instruction to do this, and set a new default:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# ALTER <ATTRIBUTE> SET DEFAULT <NEW DEFAULT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# ALTER isDiscontinued SET DEFAULT 0;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'YES', '', '', ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# We can also impose `productName` to be not-null by altering the table one final time.
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | productID   | Integer | | NOT NULL AUTO_INCREMENT |
# | productName | String | Max length 30 | **NOT NULL** DEFAULT '' |
# | unitPrice   | Float | | NOT NULL DEFAULT 99999.99|
# | unitsInStock | Integer | Unsigned | NOT NULL DEFAULT 0 |
# | isDiscontinued  | Bool | | NOT NULL DEFAULT 0 |
#
#
# In MySQL, this implies modifying the entire attribute, thus the Type will have to be re-stated:
#
# ```mysql
# ALTER TABLE <THE TABLE>
# MODIFY <ATTRIBUTE> <ATTRIBUTE TYPE> <CONSTRAINT>;
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE products
# MODIFY productName VARCHAR(30) NOT NULL;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('productID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('productName', 'varchar(30)', 'NO', '', None, ''),
#  ('unitPrice', 'float', 'NO', '', '100000', ''),
#  ('unitsInStock', 'int unsigned', 'NO', '', '0', ''),
#  ('isDiscontinued', 'tinyint(1)', 'NO', '', '0', '')]

# %% [markdown]
# Let's now create a `suppliers` table with the following description:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | supplierID   | Integer | | NOT NULL AUTO_INCREMENT |
# | supplierName | String | Max length 30 | NOT NULL DEFAULT "" |
# | countryCode   | Char | Length 3 | NOT NULL |
# | email   | String | Max length 30  | NOT NULL |
#
# `supplierID` is going to act as the table's primary key in this case.

# %%
# %%sql
#
# # create the suppliers table
# CREATE TABLE suppliers (
#     supplierID      INT NOT NULL UNIQUE AUTO_INCREMENT PRIMARY KEY,
#     supplierName    VARCHAR(30) NOT NULL DEFAULT "",
#     countryCode     CHAR(3) NOT NULL,
#     email           VARCHAR(30) NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', None, ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# Alter the table to include a default "ITA" for `countryCode`

# %%
# %%sql
#
# # alter the table
# ALTER TABLE suppliers
# ALTER countryCode SET DEFAULT "ITA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', 'ITA', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %% [markdown]
# To establish a relation between the `products` and `suppliers` tables, we have to consider that:
#
# - a supplier can supply multiple products
# - a product can be supplied by multiple suppliers
#
# This is a **many-to-many** relationship, which requires a supporting external table.
#
# To establish a many-to-many relationship between the products and suppliers tables, we create a junction table named `supplier_to_product` with foreign keys referencing the `productID` from the `products` table and the `supplierID` from the `suppliers` table.
#
# Create a new `supplier_to_product` table with the following attributes:
#
# | Attribute | Type | Extra info | Constraint |
# | --- | --- | --- |--- |
# | prodID   | Integer | | NOT NULL |
# | supID    | Integer | | NOT NULL |

# %%
# %%sql
#
# # create the support table
# CREATE TABLE supplier_to_product (
#     prodID     INT NOT NULL,
#     supID      INT NOT NULL
# );
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %% [markdown]
# Neither `prodID` nor `supID` is a good primary key in this case, as we can have both appearing multiple times in the table.
#
# However, a good primary key for this table is the combination `(prodID,supID)` which is unique, and thus, a good key.
#
# We can alter the table to add the primary key statement:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD PRIMARY KEY (<ATTRIBUTE 1>, <ATTRIBUTE 2>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD PRIMARY KEY (prodID, supID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# Finally, we can link the 3 tables together by stating which attributes act as the foreign keys in the `supplier_to_product` table, and to which attributes in the parent tables they refer to.
#
# - `prodID` points to the `productID` attribute of `products` table
# - `supID` points to the `supplierID` attribute of `supplier` table
#
# This translates into:
# - `prodID` is a foreign key for `supplier_to_product`
# - `subID` is a foreign key for `supplier_to_product`
# - the combination `(prodID, supID)` is the primary key of `supplier_to_product`
#
# We can declare an attribute as a foreign key by altering the table:
#
# ```mysql
# ALTER TABLE <TABLE>
# ADD FOREIGN KEY (<ATTRIBUTE IN THIS TABLE>) REFERENCES <OTHER TABLE>(<ATTRIBUTE IN OTHER TABLE>);
# ```

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_prod
# FOREIGN KEY (prodID) REFERENCES products(productID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # alter the table
# ALTER TABLE supplier_to_product
# ADD CONSTRAINT FK_sup
# FOREIGN KEY (supID) REFERENCES suppliers(supplierID);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # inspect the table schema
# DESCRIBE supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('prodID', 'int', 'NO', 'PRI', None, ''),
#  ('supID', 'int', 'NO', 'PRI', None, '')]

# %% [markdown]
# ## 04 Inserting Updating and Deleting records

# %% [markdown]
# The tables are currently empty.
# We can inspect their content by performing a simple "read" query using `SELECT`.
# We will discuss later the full syntax of the `SELECT` statement... for the time being, it's important to realize that this command will show the entire content of all columns of the table we are inspecting.
#
# ```mysql
# SELECT * FROM <TABLE>;
# ```
#
# To insert a single record into a table we can proceed in either of the two following ways:
#
# 1. By explicitly specifying the names of the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES (<VALUE1>, <VALUE2>, <VALUE3>, ...);
# ```
# This will work also in the case attributes with a default value will not be explicitly passed
#
#
# 2. By implicitly using all the columns when passing the tuple containing the values
# ```mysql
# INSERT INTO <TABLE>
# VALUES (<VALUE1>, <VALUE2>, ..., <VALUEn>);
# ```
#
# **NB**: 1. is the usually recommended way to perform a data insertion in SQL, as (pretty much always in coding) **explicit is better than implicit**

# %% [markdown]
# Using the `mysql.connector` we can formulate the same data insertion in a more Pythonic way, e.g. to include this statement programmatically into a loop or a function call:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = (<VALUE1>, <VALUE2>, <VALUE3>, ...)
# db_cursor.execute(sql_, val_)
# db.commit()
# ```
#
# Being an active change to the database instance, remember to commit the insert.

# %% [markdown]
# #### Perform a simple data insertion
#
# - Verify that the product table is actually empty.
# - Insert the following list of products into the `products` table.
# - Check the content of the table after the transaction to verify that both the `AUTO_INCREMENT` key and the default values have been taken into account.
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Founders Porter" | 4.9 | 12 | 0 |

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO products (productName, unitPrice, unitsInStock)
# VALUES ('Founders Porter',4.9 ,12);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# Multi-values insert can be performed in a similar way by separating multiple tuples with a comma:
#
# ```mysql
# INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...)
# VALUES
# (<VALUE11>, <VALUE12>, <VALUE13>, ...),
# (<VALUE21>, <VALUE22>, <VALUE23>, ...),
# (<VALUE31>, <VALUE32>, <VALUE33>, ...);
# ```
#
#
# The Python-based command is similar to the previous one, but it drops the `execute` in favor of `executemany`, using a list of tuples as values:
#
# ```python
# sql_ = "INSERT INTO <TABLE> (<COLUMN1>, <COLUMN2>, <COLUMN3>, ...) VALUES (%s, %s, %s, ...)"
# val_ = [
#     (<VALUE11>, <VALUE12>, <VALUE13>, ...),
#     (<VALUE21>, <VALUE22>, <VALUE23>, ...),
#     (<VALUE31>, <VALUE32>, <VALUE33>, ...) ]
# db_cursor.executemany(sql_, val_)
# db.commit()
# ```

# %% [markdown]
# Add a few more products to the `product` table:
#
# | productName | unitPrice | unitsInStock | isDiscontinued |
# | --- | --- | --- |--- |
# | "Punk IPA" | 5.2 | 45 |  |
# | "HB Dunkel" | 4.5 | 250 |  |
# | "Forst Xmas " | 8.0 | 2 |  |
# | "Damm Complot " | 3.7 | 120 |  |

# %%
# insert records into the table
sql_ = "INSERT INTO products (productName, unitPrice, unitsInStock) VALUES (%s, %s, %s)"
val_ = [
    ('Punk IPA',     5.2,  45),
    ('HB Dunkel',    4.5, 250),
    ('Forst Xmas',   8.0,   2),
    ('Damm Complot', 3.7, 120)]
dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM products"); 
dbc.fetchall()
# Out:
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# Updating entries is a delicate issue in databases, as we can potentially modify all records associated with a number of conditions. This makes the update operation quite powerful and possibly error-prone if not performed with extreme caution.
#
# ```mysql
# UPDATE <TABLE>
# SET <ATTRIBUTE> = <NEW VALUE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "UPDATE <TABLE> SET <ATTRIBUTE> = <NEW VALUE> WHERE <CONDITION>"
# db_cursor.execute(sql_)
# db.commit()
#
# ```
#
# #### Let's update a single record with a "very explicit" condition statement:
#
# - Assign `isDiscontinued` equal to `1` to the "Forst Xmas" product.
# - Check if the update has taken place.

# %%
# %%sql
#
# # update the content of the table
# UPDATE products
# SET isDiscontinued = 1
# WHERE productName = "Forst Xmas";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (4, 'Forst Xmas', 8.0, 2, 1),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# Similarly, deleting entries is quite risky if not done with plenty of caution, as a wrong `WHERE` condition might inadvertently lead to the deletion of a large part of your database records.
#
# Remember, with `DELETE`, we remove entire records (i.e., tuples) from the database, not just the content of the `WHERE` conditional statement.
#
# ```mysql
# DELETE FROM <TABLE>
# WHERE <CONDITION>;
# ```
#
# or
#
# ```python
# sql_ = "DELETE FROM <TABLE> WHERE <CONDITION>"
# db_cursor.execute(sql)
# db.commit()
#
# ```
#
# #### Delete all records under a set of conditions:
#
# - Delete all products whose name begins with 'F' and ends with 's'.
# - Check if the deletion has taken place.

# %%
# %%sql
#
# # delete records from the table
# DELETE FROM products
# WHERE productName LIKE "F%s";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %% [markdown]
# #### Populate the `suppliers` table according to the following list
#
# | supplierName | countryCode | email|
# | --- | --- | ---|
# | "A hop in the park" | "USA" | "contactme@ahop.com" |
# | "Allez Hops! Cave à bièr" | "FRA" | "itsme@allezhops.com" |
# | "Wild Hops " | "ITA" | "myemail@wildhops.it" |
# |"Beer Paradise"|"ITA"|"beer@beerparadise.it"|

# %%
# %%sql
#
# # insert records into the table
# INSERT INTO suppliers (supplierName, countryCode, email) VALUES
# ("A hop in the park","USA","contactme@ahop.com"),
# ("Allez Hops! Cave à bièr","FRA","itsme@allezhops.com"),
# ("Wild Hops","ITA","myemail@wildhops.it"),
# ("Beer Paradise","ITA","beer@beerparadise.it");
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# []

# %%
# %%sql
#
# # retrieve the content of the table
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'contactme@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %% [markdown]
# Complete the database with the two additional steps:
#
# - Update the "A hop in the park" email address to "anewemail@ahop.com"
# - Populate the table of connections between products and suppliers
#     - Remember that the `supplier_to_product` table is linked to the other two via the respective Foreign Keys
#
# | supplier | products provided |
# | --- | --- |
# | "A hop in the park" | "Punk IPA", "HB Dunkel" |

# %%
sql_ = "UPDATE suppliers SET email = %s WHERE supplierName LIKE %s;"
val_ = ('anewemail@ahop.com', 'A hop%')
dbc.execute(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM suppliers"); 
for _ in dbc:
     print(_)
# Out:
# (1, 'A hop in the park', 'USA', 'anewemail@ahop.com')
# (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com')
# (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it')
# (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')

# %%
# %%sql
#
# SELECT * FROM products;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0)]

# %%
# %%sql
#
# SELECT * FROM suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com'),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com'),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it'),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it')]

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# []

# %%
# %%sql
#
# INSERT INTO supplier_to_product
# VALUES
# (2,1),
# (3,1);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM supplier_to_product;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(2, 1), (3, 1)]

# %% [markdown]
# Export the DB you have created into a .sql file, and store it for later use.
#
# 1. Connect to the "server" Docker container using bash
# 2. Dump the database using the `mysqldump` command
# ```bash
# $ mysqldump -u <USER> -p <DB NAME>  >  <FULL/PATH/TO/NEW/DB_DUMP.sql>
# ```
# 3. use the folder `/mapd-workspace/dbs` to store the file, as it's the one currently visible from both in- and outside the container

# %% [markdown]
# ## 04 Basic queries

# %% [markdown]
# The `SELECT` statement allows us to perform queries and retrieve data from a DB.
#
# We can perform queries on a single table in the DB, as well as perform complex queries that span multiple interconnected tables, with one-to-one, one-to-many, and many-to-many relationships across records.
#
# Any `SELECT` statement is composed of at least:
#
# ```sql
# SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>   --# the list of attributes to show
#                                                   --# the * wildcard symbol means ALL attributes
#
# FROM <TABLE1>, <TABLE2>                           --# the table, or list of tables
#                                                   --# from which to extract the attributes
#
# WHERE <CONDITIONS>                                --# (optional) condition statement
# ```
#
# The same structure applies to Python-based connectors:
#
# ```python
# db_cursor.execute("""
#     SELECT <TABLE1.ATTRIBUTE1>, <TABLE2.ATTRIBUTE2>
#     FROM <TABLE1>, <TABLE2>
#     WHERE <CONDITIONS>
# """)
# res_ = db_cursor.fetchall()
# for _ in res_:
#     print(_)
# ```
#
# As an alternative, `db_cursor.fetchone()` can be used to print out only one of possibly many records.

# %% [markdown]
# #### Get the email of all suppliers from Italy

# %%
# %%sql
#
# SELECT email
# FROM suppliers
# WHERE countryCode="ITA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %% [markdown]
# #### Get all information for products with unit price greater than 4

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice>4;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [(1, 'Founders Porter', 4.9, 12, 0),
#  (2, 'Punk IPA', 5.2, 45, 0),
#  (3, 'HB Dunkel', 4.5, 250, 0)]

# %% [markdown]
# #### Select all products with unit cost less than 5, and list them in descending order of units in stock

# %%
# %%sql
#
# SELECT *
# FROM products
# WHERE unitPrice<5
# ORDER BY unitsInStock DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [(3, 'HB Dunkel', 4.5, 250, 0),
#  (5, 'Damm Complot', 3.7, 120, 0),
#  (1, 'Founders Porter', 4.9, 12, 0)]

# %% [markdown]
# **Group by** is a common statement that allows us to perform data aggregation.
#
# If you're familiar with `pandas`, this should not be new to you.
#
# Just remember:
# 1. No group by statement is possible without an aggregation function.
# 2. Group by operations can be quite computationally expensive. In the case of large databases, group by operations might require a long time to execute.

# %% [markdown]
# #### Plot the distribution of suppliers by country

# %%
# %%sql
#
# DESCRIBE suppliers;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('supplierID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('supplierName', 'varchar(30)', 'NO', '', '', ''),
#  ('countryCode', 'char(3)', 'NO', '', 'ITA', ''),
#  ('email', 'varchar(30)', 'NO', '', None, '')]

# %%
res_ = %sql SELECT COUNT(countryCode) AS count, countryCode FROM suppliers GROUP BY countryCode;

print (res_);

res_.bar();
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# +-------+-------------+
# | count | countryCode |
# +-------+-------------+
# |   1   |     USA     |
# |   1   |     FRA     |
# |   2   |     ITA     |
# +-------+-------------+

# %% [markdown]
# The main strength of Relational DBs is the possibility of matching information from different tables through **Join** operations.
#
# A join, either performed explicitly or implicitly is:
#
# 1. Computationally expensive. In the case of large databases, join operations might require a long time to execute.
# 2. Very easy to be done wrong, thus resulting in non-meaningful results.
#
# Be sure of which attributes (most often keys) you are performing a join operation on.

# %% [markdown]
# #### Join the `supplier_to_product` table with the `suppliers` table

# %%
# %%sql
#
# SELECT *
# FROM suppliers, supplier_to_product
# WHERE supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# LEFT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1),
#  (2, 'Allez Hops! Cave à bièr', 'FRA', 'itsme@allezhops.com', None, None),
#  (3, 'Wild Hops', 'ITA', 'myemail@wildhops.it', None, None),
#  (4, 'Beer Paradise', 'ITA', 'beer@beerparadise.it', None, None)]

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# RIGHT JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1)]

# %% [markdown]
# We can concatenate multiple join operations to extract higher-level information out of the connections stored in the database.
#
# #### Add the corresponding product names to the previous join

# %%
# %%sql
#
# SELECT *
# FROM suppliers
# INNER JOIN supplier_to_product ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 2 rows affected.
# [(1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 2, 1, 2, 'Punk IPA', 5.2, 45, 0),
#  (1, 'A hop in the park', 'USA', 'anewemail@ahop.com', 3, 1, 3, 'HB Dunkel', 4.5, 250, 0)]

# %% [markdown]
# The conjunction of `SELECT`, `GROUP BY`, and `JOIN` statements will allow us to extract non-trivial information out of any Relational database.
#
# #### Add the following records to the `supplier_to_product` table, and perform the following queries:
#
# | supplier | products provided |
# | --- | --- |
# | "Wild Hops" | "Founders Porter", "Punk IPA", "HB Dunkel", "Damm Complot" |
# | "Beer Paradise" | "Punk IPA", "Damm Complot" |
# | "Allez Hops! Cave à bièr" | "Founders Porter", "HB Dunkel" |
#
# 1. show all suppliers of "Damm Complot"
# 2. retrieve the email address of all possible suppliers of "Punk IPA"
# 3. list the unit price of all products supplied by Italian firms, listed in descending order (of unit price)

# %%
sql_ = "INSERT INTO supplier_to_product (prodID, supID) VALUES (%s, %s)"
val_ = [
    # supplier Allez Hops
    (1, 2),
    (3, 2),

    # supplier Wild Hops
    (1, 3),
    (2, 3),
    (3, 3),
    (5, 3),

    # supplier Beer Paradise
    (2, 4),
    (5, 4),
]


dbc.executemany(sql_, val_)
db.commit()
     
dbc.execute("SELECT * FROM supplier_to_product"); 
for _ in dbc:
     print(_)
# Out:
# (2, 1)
# (3, 1)
# (1, 2)
# (3, 2)
# (1, 3)
# (2, 3)
# (3, 3)
# (5, 3)
# (2, 4)
# (5, 4)

# %%
# %%sql
#
# SELECT suppliers.supplierName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('A hop in the park',), ('Wild Hops',), ('Beer Paradise',)]

# %%
# %%sql
#
# SELECT suppliers.email
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE products.productName = "Punk IPA";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('anewemail@ahop.com',), ('myemail@wildhops.it',), ('beer@beerparadise.it',)]

# %%
# %%sql
#
# SELECT DISTINCT products.unitPrice, products.productName
# FROM supplier_to_product
# INNER JOIN suppliers ON supplier_to_product.supID = suppliers.supplierID
# INNER JOIN products ON supplier_to_product.prodID = products.productID
# WHERE suppliers.countryCode = "ITA"
# ORDER BY unitPrice DESC;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [(5.2, 'Punk IPA'),
#  (4.9, 'Founders Porter'),
#  (4.5, 'HB Dunkel'),
#  (3.7, 'Damm Complot')]

# %% [markdown]
# ## 05 Queries on well-formed DBs
#
# In MySQL, we can load entire databases from external files.
#
# The files will contain the full database structure (tables and constraints) and will populate all tables with all records.
#
# To load a database into the MySQL server from the interactive Docker shell, we can simply do the following:
#
# 1. Create a new database named `world`.
# 2. Import the content of the file `/mapd-workspace/dbs/world.sql` into the newly created database via:
#
# ```bash
# $ mysql -u root -p world < /mapd-workspace/dbs/world.sql
# ```
#
# **NB**: The `/mapd-workspace` directory has been defined as a Docker Volume and is a shared location with your computer.

# %% [markdown]
# #### Using the `world` DB, perform queries to answer the following questions.
#
# Additional references can be found here https://dev.mysql.com/doc/world-setup/en/
#
#
# Use a **single query** to answer the questions:
#
# 1. Which country has the largest population?
# 2. Get the total number of cities in Canada.
# 3. Select the country with the most cities.
# 4. List all the languages spoken in the Southeast Asia region.
# 5. Identify the 5 most spoken languages by number of countries.
# 6. What is the total population of the cities in the Caribbean region?
# 7. What Countries have a City named "Kingston"?
# 8. Plot the population density by country, limiting to the 25 with the least density.
# 9. Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP.
# 10. Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language.
#
#
# ##### Suggestions:
# - Start by inspecting the database tables' structure
# - When in doubt, check the table content by selecting only a few lines (use `LIMIT` to avoid returning all records)
# - Before finalizing the query, you can always perform "intermediate" queries to check if complex operations (e.g. `GROUP BY` and `JOIN`) are stated correctly

# %%
# %%sql
#
# USE world;
#
# SHOW TABLES;
# Out:
# 0 rows affected.
# 3 rows affected.
# [('city',), ('country',), ('countrylanguage',)]

# %%
# %%sql
#
# DESCRIBE city
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('ID', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('Name', 'char(35)', 'NO', '', '', ''),
#  ('CountryCode', 'char(3)', 'NO', 'MUL', '', ''),
#  ('District', 'char(20)', 'NO', '', '', ''),
#  ('Population', 'int', 'NO', '', '0', '')]

# %%
# %%sql
#
# SELECT *
# FROM city
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Kabul', 'AFG', 'Kabol', 1780000),
#  (2, 'Qandahar', 'AFG', 'Qandahar', 237500),
#  (3, 'Herat', 'AFG', 'Herat', 186800),
#  (4, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800),
#  (5, 'Amsterdam', 'NLD', 'Noord-Holland', 731200)]

# %%
# %%sql
#
# DESCRIBE country
# Out:
#  * mysql+mysqlconnector://root:***@db
# 15 rows affected.
# [('Code', 'char(3)', 'NO', 'PRI', '', ''),
#  ('Name', 'char(52)', 'NO', '', '', ''),
#  ('Continent', "enum('Asia','Europe','North America','Africa','Oceania','Antarctica','South America')", 'NO', '', 'Asia', ''),
#  ('Region', 'char(26)', 'NO', '', '', ''),
#  ('SurfaceArea', 'decimal(10,2)', 'NO', '', '0.00', ''),
#  ('IndepYear', 'smallint', 'YES', '', None, ''),
#  ('Population', 'int', 'NO', '', '0', ''),
#  ('LifeExpectancy', 'decimal(3,1)', 'YES', '', None, ''),
#  ('GNP', 'decimal(10,2)', 'YES', '', None, ''),
#  ('GNPOld', 'decimal(10,2)', 'YES', '', None, ''),
#  ('LocalName', 'char(45)', 'NO', '', '', ''),
#  ('GovernmentForm', 'char(45)', 'NO', '', '', ''),
#  ('HeadOfState', 'char(60)', 'YES', '', None, ''),
#  ('Capital', 'int', 'YES', '', None, ''),
#  ('Code2', 'char(2)', 'NO', '', '', '')]

# %% [markdown]
# #### 1 - Which country has the largest population?

# %%
# %%sql
#
# SELECT  Name,Population FROM country
# ORDER BY  Population   DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('China', 1277558000)]

# %% [markdown]
# #### 2 - Get the total number of cities in Canada.

# %%
# %%sql
#
# SELECT CountryCode AS Country, COUNT(CountryCode) AS N_Cities FROM city
# WHERE CountryCode = "CAN"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('CAN', 49)]

# %% [markdown]
# #### 3 - Select the country with the most cities.

# %%
# %%sql
#
# SELECT CountryCode AS Country, COUNT(CountryCode) AS n FROM city
# GROUP BY CountryCode
# ORDER BY n DESC
# LIMIT 1
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('CHN', 363)]

# %% [markdown]
# #### 4 - List all the languages spoken in the Southeast Asia region.

# %%
# %%sql
#
# SELECT DISTINCT(cl.Language) FROM countrylanguage cl
#
# LEFT JOIN country c ON cl.CountryCode=c.Code
# WHERE c.Region = "Southeast Asia"
# AND cl.IsOfficial=1
#
# GROUP BY cl.Language
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Malay',),
#  ('Khmer',),
#  ('Lao',),
#  ('Burmese',),
#  ('Pilipino',),
#  ('Chinese',),
#  ('Tamil',),
#  ('Thai',),
#  ('Portuguese',),
#  ('Vietnamese',)]

# %% [markdown]
# #### 5 - Identify the 5 most spoken languages by number of countries.

# %%
# %%sql
#
# SELECT cl.Language, COUNT(cl.Language) AS n FROM countrylanguage cl
#
# LEFT JOIN country c ON cl.CountryCode=c.Code
# AND cl.IsOfficial=1
#
# GROUP BY cl.Language
# ORDER BY n DESC
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('English', 60),
#  ('Arabic', 33),
#  ('Spanish', 28),
#  ('French', 25),
#  ('German', 19)]

# %% [markdown]
# #### 6 - What is the total population of the cities in the Caribbean region?

# %%
# %%sql
# SELECT * FROM city
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [(1, 'Kabul', 'AFG', 'Kabol', 1780000),
#  (2, 'Qandahar', 'AFG', 'Qandahar', 237500),
#  (3, 'Herat', 'AFG', 'Herat', 186800),
#  (4, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800),
#  (5, 'Amsterdam', 'NLD', 'Noord-Holland', 731200)]

# %%
# %%sql
# SELECT SUM(ct.Population) AS Population FROM city ct
# LEFT JOIN country co ON ct.CountryCode = co.Code
# WHERE Region = "Caribbean"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(Decimal('11067550'),)]

# %% [markdown]
# #### 7 - What Countries have a City named "Kingston"?

# %%
# %%sql
#
# SELECT COUNT(CT.Name) AS n FROM city CT
# LEFT JOIN country CO ON CT.CountryCode = CO.Code
# WHERE CT.Name LIKE "Kingston%"
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(3,)]

# %% [markdown]
# #### 8 - Plot the population density by country, limiting to the 25 with the least density.

# %% [markdown]
# The population density is the total `Population` of a country divided by the `SurfaceArea`.
# We can compute this quantity on the fly during a `SELECT` statement and rename it with an `ALIAS` for convenience.

# %%
from matplotlib import pyplot as plt
res_ = %sql SELECT DISTINCT(Code), Population/SurfaceArea AS Population_Density FROM country WHERE Population>0 ORDER BY Population_Density ASC LIMIT 25 ;
# We use it in a python variable
print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 25 rows affected.
# +------+--------------------+
# | Code | Population_Density |
# +------+--------------------+
# | GRL  |       0.0259       |
# | SJM  |       0.0513       |
# | FLK  |       0.1643       |
# | PCN  |       1.0204       |
# | ESH  |       1.1015       |
# | MNG  |       1.6993       |
# | GUF  |       2.0111       |
# | NAM  |       2.0939       |
# | AUS  |       2.4397       |
# | SUR  |       2.5541       |
# | MRT  |       2.6036       |
# | ISL  |       2.7087       |
# | BWA  |       2.7882       |
# | CAN  |       3.1239       |
# | LBY  |       3.1855       |
# | GUY  |       4.0052       |
# | GAB  |       4.5803       |
# | CAF  |       5.8027       |
# | KAZ  |       5.9536       |
# | TCD  |       5.9587       |
# | BOL  |       7.5816       |
# | NIU  |       7.6923       |
# | OMN  |       8.2132       |
# | NER  |       8.4688       |
# | RUS  |       8.6050       |
# +------+--------------------+

# %% [markdown]
# #### 9 - Plot the GNP (Gross Nation Product) of all countries that become independent between 1850 and 1910, limiting to the 10 with the highest GNP

# %% [markdown]
# We can use `BETWEEN a AND b` to select only those entries between two extremes;

# %%
# %%sql
# SELECT * FROM country
# WHERE IndepYear BETWEEN 1850 AND 1910
# ORDER BY GNP DESC
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('ITA', 'Italy', 'Europe', 'Southern Europe', Decimal('301316.00'), 1861, 57680000, Decimal('79.0'), Decimal('1161755.00'), Decimal('1145372.00'), 'Italia', 'Republic', 'Carlo Azeglio Ciampi', 1464, 'IT'),
#  ('CAN', 'Canada', 'North America', 'North America', Decimal('9970610.00'), 1867, 31147000, Decimal('79.4'), Decimal('598862.00'), Decimal('625626.00'), 'Canada', 'Constitutional Monarchy, Federation', 'Elisabeth II', 1822, 'CA'),
#  ('AUS', 'Australia', 'Oceania', 'Australia and New Zealand', Decimal('7741220.00'), 1901, 18886000, Decimal('79.8'), Decimal('351182.00'), Decimal('392911.00'), 'Australia', 'Constitutional Monarchy, Federation', 'Elisabeth II', 135, 'AU'),
#  ('IRN', 'Iran', 'Asia', 'Southern and Central Asia', Decimal('1648195.00'), 1906, 67702000, Decimal('69.7'), Decimal('195746.00'), Decimal('160151.00'), 'Iran', 'Islamic Republic', 'Ali Mohammad Khatami-Ardakani', 1380, 'IR'),
#  ('NOR', 'Norway', 'Europe', 'Nordic Countries', Decimal('323877.00'), 1905, 4478500, Decimal('78.7'), Decimal('145895.00'), Decimal('153370.00'), 'Norge', 'Constitutional Monarchy', 'Harald V', 2807, 'NO'),
#  ('ZAF', 'South Africa', 'Africa', 'Southern Africa', Decimal('1221037.00'), 1910, 40377000, Decimal('51.1'), Decimal('116729.00'), Decimal('129092.00'), 'South Africa', 'Republic', 'Thabo Mbeki', 716, 'ZA'),
#  ('NZL', 'New Zealand', 'Oceania', 'Australia and New Zealand', Decimal('270534.00'), 1907, 3862000, Decimal('77.8'), Decimal('54669.00'), Decimal('64960.00'), 'New Zealand/Aotearoa', 'Constitutional Monarchy', 'Elisabeth II', 3499, 'NZ'),
#  ('ROM', 'Romania', 'Europe', 'Eastern Europe', Decimal('238391.00'), 1878, 22455500, Decimal('69.9'), Decimal('38158.00'), Decimal('34843.00'), 'România', 'Republic', 'Ion Iliescu', 3018, 'RO'),
#  ('CUB', 'Cuba', 'North America', 'Caribbean', Decimal('110861.00'), 1902, 11201000, Decimal('76.2'), Decimal('17843.00'), Decimal('18862.00'), 'Cuba', 'Socialistic Republic', 'Fidel Castro Ruz', 2413, 'CU'),
#  ('LUX', 'Luxembourg', 'Europe', 'Western Europe', Decimal('2586.00'), 1867, 435700, Decimal('77.1'), Decimal('16321.00'), Decimal('15519.00'), 'Luxembourg/Lëtzebuerg', 'Constitutional Monarchy', 'Henri', 2452, 'LU')]

# %%
res_ = %sql SELECT Name, GNP FROM country\
    WHERE IndepYear BETWEEN 1850 AND 1910\
    ORDER BY GNP DESC \
    LIMIT 10;
print(res_)

plt.figure(figsize=(16,3))
res_.bar();
plt.xticks(rotation='vertical');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# +--------------+------------+
# |     Name     |    GNP     |
# +--------------+------------+
# |    Italy     | 1161755.00 |
# |    Canada    | 598862.00  |
# |  Australia   | 351182.00  |
# |     Iran     | 195746.00  |
# |    Norway    | 145895.00  |
# | South Africa | 116729.00  |
# | New Zealand  |  54669.00  |
# |   Romania    |  38158.00  |
# |     Cuba     |  17843.00  |
# |  Luxembourg  |  16321.00  |
# +--------------+------------+

# %% [markdown]
# #### 10 - Create a scatter plot of the life expectancy vs the GNP of all countries that have Spanish as their Official language

# %%
# %%sql
# SELECT C.Name AS Country, C.LifeExpectancy, C.GNP AS GNP FROM country C
# LEFT JOIN countrylanguage CL ON C.Code = CL.CountryCode
# WHERE Language = "Spanish" AND IsOfficial = 1
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('Argentina', Decimal('75.1'), Decimal('340238.00')),
#  ('Bolivia', Decimal('63.7'), Decimal('8571.00')),
#  ('Chile', Decimal('75.7'), Decimal('72949.00')),
#  ('Colombia', Decimal('70.3'), Decimal('102896.00')),
#  ('Costa Rica', Decimal('75.8'), Decimal('10226.00')),
#  ('Cuba', Decimal('76.2'), Decimal('17843.00')),
#  ('Dominican Republic', Decimal('73.2'), Decimal('15846.00')),
#  ('Ecuador', Decimal('71.1'), Decimal('19770.00')),
#  ('Spain', Decimal('78.8'), Decimal('553233.00')),
#  ('Guatemala', Decimal('66.2'), Decimal('19008.00'))]

# %%
res_ = %sql SELECT C.LifeExpectancy, C.GNP, C.Name AS Country  FROM country C\
LEFT JOIN countrylanguage CL ON C.Code = CL.CountryCode\
WHERE Language = "Spanish" AND IsOfficial = 1;

print(res_)

plt.figure(figsize=(8,6))
for _ in res_:
    plt.scatter(_[0],_[1],s=50);
    plt.annotate(_[2], (float(_[0])*1.002,float(_[1])*1.002));
plt.ylabel('GNP')
plt.xlabel('LifeExpectancy')
# Out:
#  * mysql+mysqlconnector://root:***@db
# 20 rows affected.
# +----------------+-----------+--------------------+
# | LifeExpectancy |    GNP    |      Country       |
# +----------------+-----------+--------------------+
# |      75.1      | 340238.00 |     Argentina      |
# |      63.7      |  8571.00  |      Bolivia       |
# |      75.7      |  72949.00 |       Chile        |
# |      70.3      | 102896.00 |      Colombia      |
# |      75.8      |  10226.00 |     Costa Rica     |
# |      76.2      |  17843.00 |        Cuba        |
# |      73.2      |  15846.00 | Dominican Republic |
# |      71.1      |  19770.00 |      Ecuador       |
# |      78.8      | 553233.00 |       Spain        |
# |      66.2      |  19008.00 |     Guatemala      |
# |      69.9      |  5333.00  |      Honduras      |
# |      71.5      | 414972.00 |       Mexico       |
# |      68.7      |  1988.00  |     Nicaragua      |
# |      75.5      |  9131.00  |       Panama       |
# |      70.0      |  64140.00 |        Peru        |
# |      75.6      |  34100.00 |    Puerto Rico     |
# |      73.7      |  8444.00  |      Paraguay      |
# |      69.7      |  11863.00 |    El Salvador     |
# |      75.2      |  20831.00 |      Uruguay       |
# |      73.1      |  95023.00 |     Venezuela      |
# +----------------+-----------+--------------------+
# Text(0.5, 0, 'LifeExpectancy')

# %% [markdown]
# ## 06 More on queries

# %% [markdown]
# Let's import a well-structured database, with several tables and relationships, to be used as a sandbox for further exercises on queries.
#
# The database is freely available and is taken from the IMDb (Internet Movie Database) website (https://www.imdb.com/interfaces/), although severely slimmed down.
#
# This database contains several tables with information about movies, TV shows, people involved in the entertainment industry, and more, spanning from the 1890s to recent years.
#
# To simplify the execution of queries, we will work with a slimmed-down version of the entire database, with still plenty of records for us to extract interesting information.
#
# To start working with the IMDb database, we need to import it into our environment. The database `.sql` file should be downloaded from the link on Moodle and copied into the `/mysql/dbs` folder of the GitHub repository so that it will be found in the mounted volume at the location: `/mapd-workspace/dbs/IMDb_pruned.sql`.

# %% [markdown]
# 1. Create a new DB named `IMDb`
# 2. Import the content of the file `/mapd-workspace/dbs/IMDb_pruned.sql` into the newly created DB
# (this might take a minute or two...)

# %% [markdown]
# ### Check which tables are available

# %%
# %%sql
# USE IMDb;
# SHOW TABLES;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 10 rows affected.
# [('Directors',),
#  ('Episode_belongs_to',),
#  ('Had_role',),
#  ('Names_',),
#  ('Title_genres',),
#  ('Title_ratings',),
#  ('Titles',),
#  ('WAFilms',),
#  ('filmWA',),
#  ('films',)]

# %% [markdown]
# ### Describe the content of table `Names_`

# %%
# %%sql
#
# DESCRIBE Names_
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_', 'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', 'smallint', 'YES', '', None, ''),
#  ('death_year', 'smallint', 'YES', '', None, '')]

# %% [markdown]
# ### Study the distribution of the year of birth of all people included in the database
#
# 1. Start by limiting the query to 1000 entries
#     1. Draw a histogram of the year of birth
#     1. Draw a second histogram with the year of birth of the 1000 youngest people in the list

# %%
# 1.A
import matplotlib.pyplot as plt
import numpy as np

birth_years_ = %sql SELECT birth_year FROM Names_\
LIMIT 1000;

counts, bins = np.histogram(birth_years_)
plt.hist(bins[:-1], bins, weights=counts);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1000 rows affected.

# %%
# 1.B
birth_years_ = %sql SELECT birth_year FROM Names_\
ORDER BY birth_year DESC\
LIMIT 1000;

counts, bins = np.histogram(birth_years_)
plt.hist(bins[:-1], bins, weights=counts);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1000 rows affected.

# %% [markdown]
# 2. Extend the query to all records in the table
#     1. Check for outliers (inspect min and max)
#     2. If any outlier is found, limit the query to a reasonable range (say... at least people born after 1850)
#     3. Draw a new histogram with the year of birth
#     4. Compute the mean and standard deviation of the year of birth

# %%
# %%sql
# # 2.A
#
# SELECT MIN(birth_year) AS min, MAX(birth_year) AS max FROM Names_
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(13, 2021)]

# %%
# 2.B/C
'''SELECT COUNT(*)
FROM Names_
WHERE birth_year <= 1850'''

birth_years_ = %sql SELECT birth_year FROM Names_\
WHERE birth_year >= 1850;

counts, bins = np.histogram(birth_years_)
plt.hist(bins[:-1], bins, weights=counts);
# Out:
#  * mysql+mysqlconnector://root:***@db
# 156309 rows affected.

# %%
# %%sql
# # 2.D
# SELECT AVG(birth_year), STD(birth_year) FROM Names_
# WHERE birth_year >= 1850
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [(Decimal('1965.4513'), 19.99205313179966)]

# %% [markdown]
# ### Movie stats
#
# 1. Plot the number of titles available in the database for each year over the past 25 years.
# 2. List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.
# 3. List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %% [markdown]
# #### 1 - Plot the number of titles available in the database for each year over the past 25 years.

# %%
# %%sql
# DESCRIBE Titles;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
# SELECT COUNT(start_year) AS nTitles, start_year
# FROM Titles
# WHERE start_year>=2001
# GROUP BY start_year
# ORDER BY start_year ASC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 27 rows affected.
# [(16598, 2001),
#  (16937, 2002),
#  (18189, 2003),
#  (19711, 2004),
#  (22746, 2005),
#  (24898, 2006),
#  (27860, 2007),
#  (30564, 2008),
#  (34450, 2009),
#  (35706, 2010),
#  (39155, 2011),
#  (43170, 2012),
#  (46740, 2013),
#  (50654, 2014),
#  (55864, 2015),
#  (61554, 2016),
#  (65984, 2017),
#  (66211, 2018),
#  (61580, 2019),
#  (56755, 2020),
#  (51422, 2021),
#  (6211, 2022),
#  (161, 2023),
#  (14, 2024),
#  (4, 2025),
#  (3, 2026),
#  (1, 2027)]

# %% [markdown]
# #### 2 - List the names of all actors who have portrayed the character Spider-Man in movies, along with the corresponding movie titles.

# %%
# %%sql
# DESCRIBE Names_;
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_', 'varchar(255)', 'NO', '', None, ''),
#  ('birth_year', 'smallint', 'YES', '', None, ''),
#  ('death_year', 'smallint', 'YES', '', None, '')]

# %%
# %%sql
# DESCRIBE Had_role
# Out:
#  * mysql+mysqlconnector://root:***@db
# 3 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('name_id', 'varchar(255)', 'NO', '', None, ''),
#  ('role_', 'text', 'NO', '', None, '')]

# %%
# %%sql
#
# SELECT Titles.primary_title, Names_.name_ AS name
# FROM Had_role
# JOIN Names_ ON Had_role.name_id = Names_.name_id
# JOIN Titles ON Had_role.title_id = Titles.title_id
# WHERE Had_role.role_ LIKE "Spider%Man"
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.OperationalError) 2013 (HY000): Lost connection to MySQL server during query
# [SQL: SELECT Titles.primary_title, Names_.name_ AS name
# FROM Had_role
# JOIN Names_ ON Had_role.name_id = Names_.name_id
# JOIN Titles ON Had_role.title_id = Titles.title_id
# WHERE Had_role.role_ LIKE "Spider%Man"
# LIMIT 10]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# #### 3 - List and count the top 10 people who have appeared the most in movies directed by Wes Anderson.

# %%
# %%sql
# CREATE VIEW filmWA AS
# #CREATING A VIEW TABLE CONTAINING ALL THE IDS OF THE MOVIES DIRECTED BY WA
# SELECT T.title_id AS film FROM Directors D
# JOIN Names_ N ON D.name_id = N.name_id
# JOIN Titles T ON D.title_id = T.title_id
# WHERE N.name_ LIKE "Wes_Anderson";
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'filmWA' already exists
# [SQL: CREATE VIEW filmWA AS
# #CREATING A VIEW TABLE CONTAINING ALL THE IDS OF THE MOVIES DIRECTED BY WA
# SELECT T.title_id AS film FROM Directors D
# JOIN Names_ N ON D.name_id = N.name_id
# JOIN Titles T ON D.title_id = T.title_id
# WHERE N.name_ LIKE "Wes_Anderson";]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# SELECT * FROM filmWA
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0115734',),
#  ('tt0128445',),
#  ('tt0265666',),
#  ('tt0362270',),
#  ('tt0432283',),
#  ('tt0838221',),
#  ('tt1748122',),
#  ('tt2278388',),
#  ('tt5104604',),
#  ('tt8847712',)]

# %%
# %%sql
# SELECT COUNT(N.name_id) AS n, N.name_ AS Name
# FROM Names_ N
#
# JOIN Had_role H ON N.name_id = H.name_id
# JOIN filmWA F ON F.film = H.title_id
# GROUP BY N.name_id,N.Name_
# ORDER BY n DESC
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [(4, 'Bill Murray'),
#  (3, 'Owen Wilson'),
#  (3, 'Jason Schwartzman'),
#  (3, 'Adrien Brody'),
#  (2, 'Anjelica Huston'),
#  (1, 'Luke Wilson'),
#  (1, 'Ned Dowd'),
#  (1, 'Shea Fowler'),
#  (1, 'Tilda Swinton'),
#  (1, 'Seymour Cassel')]

# %% [markdown]
# ### Is IMDB only about movies?
# 1. Check the number of different media types contained in the database
# 1. Plot a histogram summarizing the number of titles per media type
# 1. Find the name and rating of the oldest videogame stored in the database

# %% [markdown]
# #### 1 - Check the number of different media types contained in the database

# %%
# %%sql
#
# USE IMDb;
# DESCRIBE Titles
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 5 rows affected.
# [('title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('title_type', 'varchar(50)', 'YES', '', None, ''),
#  ('primary_title', 'text', 'YES', '', None, ''),
#  ('start_year', 'int', 'YES', '', None, ''),
#  ('runtime_minutes', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT DISTINCT(title_type) FROM Titles
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('movie',), ('tvEpisode',), ('tvSeries',), ('tvMiniSeries',), ('videoGame',)]

# %% [markdown]
# #### 2 - Plot a histogram summarizing the number of titles per media type

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = %sql SELECT COUNT(title_type) AS n, title_type FROM Titles\
GROUP BY title_type;
df = pd.DataFrame(data)
df.plot(kind='bar', x='title_type', y='n', legend=False, color='skyblue');
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.

# %% [markdown]
# #### 3 - Find the name and rating of the oldest videogame stored in the database

# %%
# %%sql
# SELECT T.primary_title AS Game_Name, TR.average_rating AS Rating
# FROM Titles T
# LEFT JOIN Title_ratings TR ON T.title_id = TR.title_id
# WHERE title_type = "videoGame"
# ORDER BY start_year ASC
# LIMIT 1
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Lord of the Rings', 6.9)]

# %% [markdown]
# ### Identify interesting outliers
#
# 1. List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.
# 2. What actor had the most roles as 'Self'?
# 3. Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first- and last-episode

# %% [markdown]
# #### 1 - List the names of all movies whose titles begin with "The" and have a runtime between 3 and 4 hours.

# %%
# %%sql
# SELECT * FROM Titles
# WHERE primary_title LIKE "The%"
# AND runtime_minutes BETWEEN 180 AND 240
# AND title_type = "movie"
# LIMIT 10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 10 rows affected.
# [('tt0101428', 'movie', 'The Beautiful Troublemaker', 1991, 238),
#  ('tt0104350', 'movie', 'The Best Intentions', 1992, 180),
#  ('tt0107472', 'movie', 'The Wonderful, Horrible Life of Leni Riefenstahl', 1993, 183),
#  ('tt0109584', 'movie', 'The Decline of the Century: Testament L.Z.', 1994, 201),
#  ('tt0110894', 'movie', 'The Beginning and the End', 1993, 188),
#  ('tt0120125', 'movie', 'The Barber of Siberia', 1998, 180),
#  ('tt0120689', 'movie', 'The Green Mile', 1999, 189),
#  ('tt0133027', 'movie', 'The Year After Dayton', 1997, 204),
#  ('tt0138104', 'movie', 'The Sleep Room', 1998, 193),
#  ('tt0167260', 'movie', 'The Lord of the Rings: The Return of the King', 2003, 201)]

# %% [markdown]
# #### 2 - What actor had the most roles as 'Self'?

# %%
# %%sql
# SELECT N.name_, COUNT(H.name_id) num FROM Names_ N
# LEFT JOIN Had_role H ON N.name_id = H.name_id
# WHERE H.role_ = "Self"
# GROUP BY N.name_
# ORDER BY num DESC
# LIMIT 1
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Scott Morrison', 3197)]

# %% [markdown]
# #### 3 - Identify what TV series had more than 1,000 episodes, and identify in what year it was aired the first episode

# %%
# %%sql
# SELECT DISTINCT(title_type) FROM Titles
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('movie',), ('tvEpisode',), ('tvSeries',), ('tvMiniSeries',), ('videoGame',)]

# %%
# %%sql
#
# SELECT T.primary_title, COUNT(E.episode_title_id) n FROM Episode_belongs_to E
# RIGHT JOIN Titles T ON E.parent_tv_show_title_id = T.title_id
# WHERE T.title_type = "tvSeries"
# GROUP BY E.parent_tv_show_title_id,T.primary_title
# HAVING n>1000
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 5 rows affected.
# [('Hollyoaks', 4367),
#  ('Chelsea Lately', 1163),
#  ('Mornings with Maria Bartiromo', 2119),
#  ('Fox Report with Jon Scott', 1346),
#  ('Telefé noticias', 3248)]

# %% [markdown]
# ### It's all about the ratings
#
# 1. Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.
# 2. Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season
# 3. Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %% [markdown]
# #### 1 - Group all movies by decade and plot their overall rating distribution trend. Limit the query to the movies with at least 1000 ratings.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

range_yrs = %sql SELECT MAX(start_year) max ,MIN(start_year) min FROM Titles\
WHERE title_type = "movie";
pd_range = pd.DataFrame(range_yrs)
ran = range(pd_range["min"][0],pd_range["max"][0],10)

j = len(ran)

fig,ax = plt.subplots(j,1,figsize=(8,4*j) )

for idx,i in enumerate(ran):

    data = %sql SELECT TR.average_rating\
    FROM Titles T\
    LEFT JOIN Title_ratings TR ON T.title_id = TR.title_id\
    WHERE T.start_year BETWEEN {i} AND {i+9}\
    AND TR.num_votes > 1000;
    
    
    counts, bins = np.histogram(data)
    ax[idx].hist(bins[:-1], bins, weights=counts)
    ax[idx].set_title(f"Average rating in {i} s")
    ax[idx].vlines( np.mean(data),0,np.max(counts),color="k" )
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 6783 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 13738 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 27522 rows affected.
#  * mysql+mysqlconnector://root:***@db
# 4726 rows affected.

# %% [markdown]
# #### 2 - Plot the average rating of each episode of "Games of Thrones". Group by season and compute the average and standard deviation for each season.

# %%
# %%sql
# DESCRIBE Episode_belongs_to
# Out:
#  * mysql+mysqlconnector://root:***@db
# 4 rows affected.
# [('episode_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('parent_tv_show_title_id', 'varchar(255)', 'NO', '', None, ''),
#  ('season_number', 'int', 'YES', '', None, ''),
#  ('episode_number', 'int', 'YES', '', None, '')]

# %%
# %%sql
#
# SELECT season_number, AVG(average_rating) mean_rating, STD(average_rating) std
# FROM Episode_belongs_to EB
# LEFT JOIN Titles T ON EB.parent_tv_show_title_id = T.title_id
# LEFT JOIN Title_ratings TR ON EB.episode_title_id = TR.title_id
# WHERE T.primary_title LIKE "Game of Thrones"
# GROUP BY EB.season_number
# ORDER BY season_number
# LIMIT 100
# Out:
#  * mysql+mysqlconnector://root:***@db
# 8 rows affected.
# [(1, 9.100000095367431, 0.27928484185189195),
#  (2, 8.960000038146973, 0.33226483855981404),
#  (3, 9.05, 0.3905124105321291),
#  (4, 9.310000038146972, 0.38327525741064195),
#  (5, 8.830000019073486, 0.5273518051323893),
#  (6, 9.05999984741211, 0.588557477116479),
#  (7, 9.099999972752162, 0.37416567313687316),
#  (8, 6.333333412806193, 1.3634107864471021)]

# %% [markdown]
# #### 3 - Plot the total number of movies produced per year, divided by genre (Action, Comedy, Drama, Thriller, Fantasy), and the yearly rating average per genre

# %%
# %%sql
#
# SELECT genre, start_year year, AVG(average_rating) mean_rating
# FROM Titles T
#
# INNER JOIN Title_genres TG ON T.title_id = TG.title_id
# INNER JOIN Title_ratings TR ON T.title_id = TR.title_id
# WHERE genre IN ("Action", "Comedy", "Drama", "Thriller", "Fantasy")
# GROUP BY genre, start_year
# HAVING start_year>0
# ORDER BY start_year
# Out:
#  * mysql+mysqlconnector://root:***@db
# 165 rows affected.
# [('Drama', 1990, 6.901019510383724),
#  ('Fantasy', 1990, 6.6588477244592985),
#  ('Action', 1990, 6.419953052706561),
#  ('Comedy', 1990, 6.936266414390123),
#  ('Thriller', 1990, 5.652093027913293),
#  ('Drama', 1991, 6.859337222987208),
#  ('Action', 1991, 6.53620309729713),
#  ('Fantasy', 1991, 6.636434113332467),
#  ('Comedy', 1991, 6.971179260172934),
#  ('Thriller', 1991, 5.617525764347351),
#  ('Comedy', 1992, 6.9844936874525025),
#  ('Fantasy', 1992, 6.960800016403199),
#  ('Action', 1992, 6.623191743439018),
#  ('Drama', 1992, 6.890048322009579),
#  ('Thriller', 1992, 5.624299063860813),
#  ('Drama', 1993, 6.926431906845391),
#  ('Comedy', 1993, 7.036721009993256),
#  ('Fantasy', 1993, 6.93168317091347),
#  ('Action', 1993, 6.651813951758451),
#  ('Thriller', 1993, 5.503734430336853),
#  ('Thriller', 1994, 5.489285699904911),
#  ('Drama', 1994, 6.9494817817050984),
#  ('Action', 1994, 6.764807851582249),
#  ('Comedy', 1994, 7.01763204105668),
#  ('Fantasy', 1994, 7.0244898095422865),
#  ('Thriller', 1995, 5.617845140322291),
#  ('Comedy', 1995, 7.004012494070212),
#  ('Drama', 1995, 6.9093454673506995),
#  ('Action', 1995, 6.858552168581484),
#  ('Fantasy', 1995, 7.121011691334647),
#  ('Drama', 1996, 6.935228468526063),
#  ('Comedy', 1996, 6.9524283515894485),
#  ('Thriller', 1996, 5.707615892618697),
#  ('Action', 1996, 6.802170666748892),
#  ('Fantasy', 1996, 7.053779091252837),
#  ('Thriller', 1997, 5.8559880278067675),
#  ('Action', 1997, 6.787483274856884),
#  ('Comedy', 1997, 6.914835360930326),
#  ('Drama', 1997, 6.864855807471963),
#  ('Fantasy', 1997, 6.55877864406309),
#  ('Comedy', 1998, 6.899368208054703),
#  ('Thriller', 1998, 5.940181267585639),
#  ('Action', 1998, 6.860903233866538),
#  ('Drama', 1998, 6.894310807840722),
#  ('Fantasy', 1998, 6.521899228410203),
#  ('Drama', 1999, 6.888031549199941),
#  ('Thriller', 1999, 5.843820214271545),
#  ('Action', 1999, 6.930898882178927),
#  ('Comedy', 1999, 6.7859598902599405),
#  ('Fantasy', 1999, 6.856223178523805),
#  ('Thriller', 2000, 5.786235953314921),
#  ('Comedy', 2000, 6.864640294133331),
#  ('Drama', 2000, 6.947612081145458),
#  ('Action', 2000, 6.9434659244661985),
#  ('Fantasy', 2000, 6.926056338587837),
#  ('Fantasy', 2001, 6.879184553039944),
#  ('Comedy', 2001, 6.93545735584787),
#  ('Drama', 2001, 7.008467524863163),
#  ('Thriller', 2001, 5.6036253767791475),
#  ('Action', 2001, 7.023577694167715),
#  ('Drama', 2002, 7.020417189481068),
#  ('Action', 2002, 6.985530382327267),
#  ('Comedy', 2002, 6.853555846719986),
#  ('Thriller', 2002, 5.983282678395419),
#  ('Fantasy', 2002, 6.7940149545074995),
#  ('Drama', 2003, 7.017886797317169),
#  ('Comedy', 2003, 6.8432738201604),
#  ('Fantasy', 2003, 7.027676254588692),
#  ('Action', 2003, 7.111274518043387),
#  ('Thriller', 2003, 5.8689944038178),
#  ('Drama', 2004, 7.058223930285124),
#  ('Comedy', 2004, 6.868697084028582),
#  ('Thriller', 2004, 6.031094530328589),
#  ('Action', 2004, 7.099368097281192),
#  ('Fantasy', 2004, 6.922832377384164),
#  ('Comedy', 2005, 6.969439901762498),
#  ('Drama', 2005, 7.083316474169414),
#  ('Action', 2005, 7.140196595115484),
#  ('Thriller', 2005, 6.033953487873077),
#  ('Fantasy', 2005, 7.225875195121475),
#  ('Drama', 2006, 7.081761959209103),
#  ('Comedy', 2006, 6.978615039149176),
#  ('Thriller', 2006, 6.000337835099246),
#  ('Fantasy', 2006, 7.127112685374811),
#  ('Action', 2006, 7.019076933860779),
#  ('Drama', 2007, 7.058882382706389),
#  ('Fantasy', 2007, 7.2759398489070115),
#  ('Comedy', 2007, 6.965839154024715),
#  ('Thriller', 2007, 5.918466894261098),
#  ('Action', 2007, 7.127870478445227),
#  ('Comedy', 2008, 6.788734481168511),
#  ('Drama', 2008, 7.016612386412263),
#  ('Fantasy', 2008, 7.105782318277424),
#  ('Action', 2008, 7.092786757268786),
#  ('Thriller', 2008, 6.10102639729676),
#  ('Thriller', 2009, 6.0909964069455755),
#  ('Drama', 2009, 7.044596572954315),
#  ('Comedy', 2009, 6.884222829009859),
#  ('Fantasy', 2009, 7.2089041251025785),
#  ('Action', 2009, 7.142389540293798),
#  ('Drama', 2010, 7.097760888995306),
#  ('Thriller', 2010, 6.063885847247654),
#  ('Comedy', 2010, 6.990251745600055),
#  ('Action', 2010, 7.111329155248962),
#  ('Fantasy', 2010, 7.280794709565623),
#  ('Comedy', 2011, 7.0592007904691005),
#  ('Thriller', 2011, 6.294573649070983),
#  ('Action', 2011, 7.223327739098493),
#  ('Drama', 2011, 7.072442770456496),
#  ('Fantasy', 2011, 7.309012481944559),
#  ('Thriller', 2012, 6.283101054122639),
#  ('Drama', 2012, 7.174690276512455),
#  ('Action', 2012, 7.215286224765979),
#  ('Comedy', 2012, 7.08192274021785),
#  ('Fantasy', 2012, 7.384338450152846),
#  ('Thriller', 2013, 6.239387468140349),
#  ('Drama', 2013, 7.171910636334239),
#  ('Comedy', 2013, 7.128296377279397),
#  ('Action', 2013, 7.239735509921453),
#  ('Fantasy', 2013, 7.168034581592222),
#  ('Comedy', 2014, 7.1840798403885335),
#  ('Action', 2014, 7.307728947327271),
#  ('Drama', 2014, 7.208450092072749),
#  ('Thriller', 2014, 6.30863946449189),
#  ('Fantasy', 2014, 7.350686112869256),
#  ('Fantasy', 2015, 7.413174126107814),
#  ('Comedy', 2015, 7.183162609948318),
#  ('Drama', 2015, 7.22709609006937),
#  ('Action', 2015, 7.314003700926355),
#  ('Thriller', 2015, 6.366989717347776),
#  ('Comedy', 2016, 7.0986826074327904),
#  ('Action', 2016, 7.207905455658626),
#  ('Thriller', 2016, 6.209283491458477),
#  ('Drama', 2016, 7.227844467772009),
#  ('Fantasy', 2016, 7.337613414570075),
#  ('Fantasy', 2017, 7.451863761273019),
#  ('Action', 2017, 7.246339668245012),
#  ('Comedy', 2017, 7.072487868287405),
#  ('Drama', 2017, 7.180370587415494),
#  ('Thriller', 2017, 6.369110518131616),
#  ('Drama', 2018, 7.131233040173283),
#  ('Comedy', 2018, 6.963955127353073),
#  ('Thriller', 2018, 6.428016578453554),
#  ('Fantasy', 2018, 7.272400330807475),
#  ('Action', 2018, 7.157246556865831),
#  ('Drama', 2019, 7.0945427164746855),
#  ('Comedy', 2019, 6.995846469779789),
#  ('Fantasy', 2019, 7.156224912333201),
#  ('Action', 2019, 7.199142166621545),
#  ('Thriller', 2019, 6.336899567834675),
#  ('Drama', 2020, 7.062256307897826),
#  ('Thriller', 2020, 6.45945036718836),
#  ('Comedy', 2020, 6.963541212114246),
#  ('Fantasy', 2020, 7.210266787579875),
#  ('Action', 2020, 6.954091248565787),
#  ('Drama', 2021, 7.166212910613344),
#  ('Comedy', 2021, 7.071711318796036),
#  ('Thriller', 2021, 6.532453837605454),
#  ('Action', 2021, 7.090546476160999),
#  ('Fantasy', 2021, 7.3231030659389384),
#  ('Action', 2022, 7.654891300460567),
#  ('Drama', 2022, 7.324390244677784),
#  ('Thriller', 2022, 6.880645158213953),
#  ('Comedy', 2022, 7.104502372267122),
#  ('Fantasy', 2022, 7.347761221786044)]

# %%
# %%sql
#
# SELECT TG.genre, T.start_year year, COUNT(1) n_films
# FROM Titles T
#
# INNER JOIN Title_genres TG ON T.title_id = TG.title_id
# INNER JOIN Title_ratings TR ON T.title_id = TR.title_id
# WHERE genre IN ("Action", "Comedy", "Drama", "Thriller", "Fantasy")
#
# GROUP BY genre, start_year
# HAVING start_year>0
# ORDER BY start_year
# Out:
#  * mysql+mysqlconnector://root:***@db
# 165 rows affected.
# [('Drama', 1990, 2256),
#  ('Fantasy', 1990, 243),
#  ('Action', 1990, 852),
#  ('Comedy', 1990, 2057),
#  ('Thriller', 1990, 215),
#  ('Drama', 1991, 2233),
#  ('Action', 1991, 906),
#  ('Fantasy', 1991, 258),
#  ('Comedy', 1991, 2120),
#  ('Thriller', 1991, 194),
#  ('Comedy', 1992, 2212),
#  ('Fantasy', 1992, 250),
#  ('Action', 1992, 871),
#  ('Drama', 1992, 2070),
#  ('Thriller', 1992, 214),
#  ('Drama', 1993, 2357),
#  ('Comedy', 1993, 2086),
#  ('Fantasy', 1993, 202),
#  ('Action', 1993, 1075),
#  ('Thriller', 1993, 241),
#  ('Thriller', 1994, 252),
#  ('Drama', 1994, 2605),
#  ('Action', 1994, 1327),
#  ('Comedy', 1994, 2348),
#  ('Fantasy', 1994, 245),
#  ('Thriller', 1995, 297),
#  ('Comedy', 1995, 2243),
#  ('Drama', 1995, 2750),
#  ('Action', 1995, 1409),
#  ('Fantasy', 1995, 257),
#  ('Drama', 1996, 2867),
#  ('Comedy', 1996, 2512),
#  ('Thriller', 1996, 302),
#  ('Action', 1996, 1336),
#  ('Fantasy', 1996, 344),
#  ('Thriller', 1997, 334),
#  ('Action', 1997, 1494),
#  ('Comedy', 1997, 2885),
#  ('Drama', 1997, 2982),
#  ('Fantasy', 1997, 524),
#  ('Comedy', 1998, 2849),
#  ('Thriller', 1998, 331),
#  ('Action', 1998, 1550),
#  ('Drama', 1998, 3076),
#  ('Fantasy', 1998, 516),
#  ('Drama', 1999, 3551),
#  ('Thriller', 1999, 356),
#  ('Action', 1999, 1602),
#  ('Comedy', 1999, 3141),
#  ('Fantasy', 1999, 466),
#  ('Thriller', 2000, 356),
#  ('Comedy', 2000, 2780),
#  ('Drama', 2000, 3413),
#  ('Action', 2000, 1760),
#  ('Fantasy', 2000, 426),
#  ('Fantasy', 2001, 466),
#  ('Comedy', 2001, 2919),
#  ('Drama', 2001, 3602),
#  ('Thriller', 2001, 331),
#  ('Action', 2001, 1828),
#  ('Drama', 2002, 4075),
#  ('Action', 2002, 1942),
#  ('Comedy', 2002, 3206),
#  ('Thriller', 2002, 329),
#  ('Fantasy', 2002, 401),
#  ('Drama', 2003, 3975),
#  ('Comedy', 2003, 3360),
#  ('Fantasy', 2003, 383),
#  ('Action', 2003, 2040),
#  ('Thriller', 2003, 358),
#  ('Drama', 2004, 4189),
#  ('Comedy', 2004, 3661),
#  ('Thriller', 2004, 402),
#  ('Action', 2004, 1899),
#  ('Fantasy', 2004, 346),
#  ('Comedy', 2005, 4267),
#  ('Drama', 2005, 4939),
#  ('Action', 2005, 1933),
#  ('Thriller', 2005, 430),
#  ('Fantasy', 2005, 657),
#  ('Drama', 2006, 5335),
#  ('Comedy', 2006, 4751),
#  ('Thriller', 2006, 592),
#  ('Fantasy', 2006, 852),
#  ('Action', 2006, 1950),
#  ('Drama', 2007, 5798),
#  ('Fantasy', 2007, 665),
#  ('Comedy', 2007, 4874),
#  ('Thriller', 2007, 574),
#  ('Action', 2007, 2038),
#  ('Comedy', 2008, 4749),
#  ('Drama', 2008, 6140),
#  ('Fantasy', 2008, 588),
#  ('Action', 2008, 2232),
#  ('Thriller', 2008, 682),
#  ('Thriller', 2009, 833),
#  ('Drama', 2009, 6866),
#  ('Comedy', 2009, 5565),
#  ('Fantasy', 2009, 730),
#  ('Action', 2009, 2444),
#  ('Drama', 2010, 6967),
#  ('Thriller', 2010, 911),
#  ('Comedy', 2010, 5919),
#  ('Action', 2010, 2701),
#  ('Fantasy', 2010, 755),
#  ('Comedy', 2011, 7157),
#  ('Thriller', 2011, 1032),
#  ('Action', 2011, 2975),
#  ('Drama', 2011, 7381),
#  ('Fantasy', 2011, 1043),
#  ('Thriller', 2012, 1148),
#  ('Drama', 2012, 7910),
#  ('Action', 2012, 3127),
#  ('Comedy', 2012, 7739),
#  ('Fantasy', 2012, 1111),
#  ('Thriller', 2013, 1404),
#  ('Drama', 2013, 8772),
#  ('Comedy', 2013, 8206),
#  ('Action', 2013, 3327),
#  ('Fantasy', 2013, 926),
#  ('Comedy', 2014, 8618),
#  ('Action', 2014, 3571),
#  ('Drama', 2014, 8994),
#  ('Thriller', 2014, 1470),
#  ('Fantasy', 2014, 1166),
#  ('Fantasy', 2015, 1298),
#  ('Comedy', 2015, 9176),
#  ('Drama', 2015, 10138),
#  ('Action', 2015, 3799),
#  ('Thriller', 2015, 1651),
#  ('Comedy', 2016, 9792),
#  ('Action', 2016, 3934),
#  ('Thriller', 2016, 1605),
#  ('Drama', 2016, 10415),
#  ('Fantasy', 2016, 1433),
#  ('Fantasy', 2017, 1556),
#  ('Action', 2017, 4057),
#  ('Comedy', 2017, 9265),
#  ('Drama', 2017, 10632),
#  ('Thriller', 2017, 1855),
#  ('Drama', 2018, 10681),
#  ('Comedy', 2018, 9269),
#  ('Thriller', 2018, 1931),
#  ('Fantasy', 2018, 1279),
#  ('Action', 2018, 4133),
#  ('Drama', 2019, 10573),
#  ('Comedy', 2019, 8571),
#  ('Fantasy', 2019, 1245),
#  ('Action', 2019, 4080),
#  ('Thriller', 2019, 1832),
#  ('Drama', 2020, 8412),
#  ('Thriller', 2020, 1783),
#  ('Comedy', 2020, 6783),
#  ('Fantasy', 2020, 1237),
#  ('Action', 2020, 2762),
#  ('Drama', 2021, 7346),
#  ('Comedy', 2021, 5002),
#  ('Thriller', 2021, 1516),
#  ('Action', 2021, 2507),
#  ('Fantasy', 2021, 883),
#  ('Action', 2022, 184),
#  ('Drama', 2022, 615),
#  ('Thriller', 2022, 155),
#  ('Comedy', 2022, 422),
#  ('Fantasy', 2022, 67)]

# %% [markdown]
# Using the world database, write a single SQL query to retrieve the average population of cities in each country that has a population greater than 10 million, grouped by continent.

# %%
# %%sql
#
# USE world;
# SELECT CO.Continent, CI.CountryCode, AVG(CI.Population) mean_pop
# FROM city CI
# JOIN country CO ON CI.CountryCode = CO.Code
# WHERE CO.Population >= 10000000
# GROUP BY CO.Continent, CI.CountryCode
# ORDER BY CO.Continent
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 78 rows affected.
# [('Asia', 'AFG', Decimal('583025.0000')),
#  ('Asia', 'BGD', Decimal('357079.4167')),
#  ('Asia', 'CHN', Decimal('484720.6997')),
#  ('Asia', 'IDN', Decimal('441008.1765')),
#  ('Asia', 'IND', Decimal('361579.2551')),
#  ('Asia', 'IRN', Decimal('388552.0896')),
#  ('Asia', 'IRQ', Decimal('595069.4000')),
#  ('Asia', 'JPN', Decimal('314375.4315')),
#  ('Asia', 'KAZ', Decimal('261152.3810')),
#  ('Asia', 'KHM', Decimal('268351.6667')),
#  ('Asia', 'KOR', Decimal('557141.3286')),
#  ('Asia', 'LKA', Decimal('220714.2857')),
#  ('Asia', 'MMR', Decimal('387687.5000')),
#  ('Asia', 'MYS', Decimal('255841.1667')),
#  ('Asia', 'NPL', Decimal('226480.6000')),
#  ('Asia', 'PAK', Decimal('534690.5932')),
#  ('Asia', 'PHL', Decimal('227461.6985')),
#  ('Asia', 'PRK', Decimal('498211.6154')),
#  ('Asia', 'SAU', Decimal('443195.8333')),
#  ('Asia', 'SYR', Decimal('407071.2727')),
#  ('Asia', 'THA', Decimal('662763.4167')),
#  ('Asia', 'TUR', Decimal('456887.5484')),
#  ('Asia', 'TWN', Decimal('323079.4286')),
#  ('Asia', 'UZB', Decimal('304935.2941')),
#  ('Asia', 'VNM', Decimal('425673.3182')),
#  ('Asia', 'YEM', Decimal('290616.6667')),
#  ('Europe', 'BEL', Decimal('178813.5556')),
#  ('Europe', 'BLR', Decimal('296312.5000')),
#  ('Europe', 'CZE', Decimal('263471.1000')),
#  ('Europe', 'DEU', Decimal('282209.4946')),
#  ('Europe', 'ESP', Decimal('282528.6271')),
#  ('Europe', 'FRA', Decimal('231112.3500')),
#  ('Europe', 'GBR', Decimal('276995.9630')),
#  ('Europe', 'GRC', Decimal('246605.3750')),
#  ('Europe', 'HUN', Decimal('328145.5556')),
#  ('Europe', 'ITA', Decimal('260121.0172')),
#  ('Europe', 'NLD', Decimal('185001.7500')),
#  ('Europe', 'POL', Decimal('265623.4318')),
#  ('Europe', 'ROM', Decimal('257551.9310')),
#  ('Europe', 'RUS', Decimal('365876.7196')),
#  ('Europe', 'UKR', Decimal('352175.4386')),
#  ('Europe', 'YUG', Decimal('273688.3750')),
#  ('North America', 'CAN', Decimal('258649.7959')),
#  ('North America', 'CUB', Decimal('330708.9286')),
#  ('North America', 'GTM', Decimal('306297.0000')),
#  ('North America', 'MEX', Decimal('345390.2948')),
#  ('North America', 'USA', Decimal('286955.3796')),
#  ('Africa', 'AGO', Decimal('512320.0000')),
#  ('Africa', 'BFA', Decimal('409666.6667')),
#  ('Africa', 'CIV', Decimal('638227.4000')),
#  ('Africa', 'CMR', Decimal('503222.0000')),
#  ('Africa', 'COD', Decimal('548034.1667')),
#  ('Africa', 'DZA', Decimal('288454.3889')),
#  ('Africa', 'EGY', Decimal('542785.9189')),
#  ('Africa', 'ETH', Decimal('455762.0000')),
#  ('Africa', 'GHA', Decimal('363977.8000')),
#  ('Africa', 'KEN', Decimal('440349.1250')),
#  ('Africa', 'MAR', Decimal('398071.0000')),
#  ('Africa', 'MDG', Decimal('224632.2000')),
#  ('Africa', 'MLI', Decimal('809552.0000')),
#  ('Africa', 'MOZ', Decimal('261928.7500')),
#  ('Africa', 'MWI', Decimal('457059.5000')),
#  ('Africa', 'NER', Decimal('217952.3333')),
#  ('Africa', 'NGA', Decimal('271357.8125')),
#  ('Africa', 'SDN', Decimal('396015.5833')),
#  ('Africa', 'SOM', Decimal('392333.3333')),
#  ('Africa', 'TZA', Decimal('294403.4000')),
#  ('Africa', 'UGA', Decimal('890800.0000')),
#  ('Africa', 'ZAF', Decimal('345372.0455')),
#  ('Africa', 'ZWE', Decimal('455070.0000')),
#  ('Oceania', 'AUS', Decimal('808119.0000')),
#  ('South America', 'ARG', Decimal('350816.8947')),
#  ('South America', 'BRA', Decimal('343507.4480')),
#  ('South America', 'CHL', Decimal('335102.4138')),
#  ('South America', 'COL', Decimal('532920.7895')),
#  ('South America', 'ECU', Decimal('382942.8000')),
#  ('South America', 'PER', Decimal('552147.3636')),
#  ('South America', 'VEN', Decimal('298807.0976'))]

# %% [markdown]
# Using the world database, write a single SQL query to retrieve the total number of languages spoken in countries that are located in Asia and have a population greater than 50 million, grouped by region.

# %%
# %%sql
#
# USE world;
#
# SELECT CO.Region, COUNT(DISTINCT(CL.Language)) AS n_languages
# FROM country CO
#
# LEFT JOIN countrylanguage CL ON CO.Code = CL.CountryCode
# WHERE CO.Continent = "Asia"
# AND CO.Population >= 50000000
# GROUP BY CO.Region
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 4 rows affected.
# [('Eastern Asia', 17),
#  ('Middle East', 3),
#  ('Southeast Asia', 30),
#  ('Southern and Central Asia', 33)]

# %% [markdown]
# Using the IMDb database, write a single SQL query to retrieve the average movie rating of movies in the "Action" genre that have a runtime of more than 90 minutes, grouped by year.

# %%
# %%sql
#
# USE IMDb;
#
# SELECT start_year, AVG(TR.average_rating) avg_rating
# FROM Titles T
#
# INNER JOIN Title_genres TG ON T.title_id = TG.title_id
# INNER JOIN Title_ratings TR ON T.title_id = TR.title_id
#
# WHERE TG.genre  ="Action"
# AND T.runtime_minutes >= 90
# GROUP BY start_year
# HAVING start_year > 0
# ORDER BY start_year
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 33 rows affected.
# [(1990, 5.69404388071975),
#  (1991, 5.557971010173577),
#  (1992, 5.676033054501557),
#  (1993, 5.693040280115037),
#  (1994, 5.574909099232067),
#  (1995, 5.601351354573224),
#  (1996, 5.56476509411063),
#  (1997, 5.759482751632559),
#  (1998, 5.824778757264129),
#  (1999, 5.895031056048707),
#  (2000, 5.7413489661258685),
#  (2001, 5.883247428948117),
#  (2002, 5.82388889392217),
#  (2003, 5.86142433538635),
#  (2004, 5.758885942024008),
#  (2005, 5.82694444987509),
#  (2006, 5.664285697596414),
#  (2007, 5.764973262414575),
#  (2008, 5.658186410776614),
#  (2009, 5.68234085106507),
#  (2010, 5.822659179958958),
#  (2011, 5.935416668427713),
#  (2012, 5.915837930491397),
#  (2013, 5.871910114732255),
#  (2014, 5.9812598566370685),
#  (2015, 6.15390280455307),
#  (2016, 6.009920633816845),
#  (2017, 5.979400269832885),
#  (2018, 5.88034433032382),
#  (2019, 5.891144414526241),
#  (2020, 5.919550160635714),
#  (2021, 6.099999993401265),
#  (2022, 6.720454535701058)]

# %% [markdown]
# Using the IMDb database, write a single SQL query to retrieve the top 5 persons who have worked in the most movies, ordered by the number of movies in which they have worked.

# %%
# %%sql
# USE IMDb;
# SELECT N.name_, COUNT(N.name_) n FROM Names_ N
# JOIN (SELECT name_id , title_id FROM Had_role
# UNION # toglie i duplicati
# SELECT name_id , title_id FROM Directors)
# AS NT ON NT.name_id = N.name_id
# JOIN Titles T ON T.title_id = NT.title_id
#
# WHERE title_type = 'movie'
#
# GROUP BY N.name_
# ORDER BY n DESC
# LIMIT 5
# Out:
# 0 rows affected.

# %% [markdown]
# Using the IMDb database, retrieve the average rating of movies in the "Comedy" genre, which were released after 2000 and have more than 100,000 votes, grouped by director, but only for directors who have directed more than 5 movies.

# %%
# %%sql
# #USE IMDb;
# SELECT N.name_ director_name, AVG(TR.average_rating) average_rating
# FROM Titles T
#
# JOIN Title_genres TG ON T.title_id = TG.title_id
# JOIN Title_ratings TR ON T.title_id = TR.title_id
# JOIN Directors D ON T.title_id = D.title_id
# JOIN Names_ N ON D.name_id = N.name_id
#
# WHERE TG.genre = "Comedy"
# AND T.title_type = "movie"
# AND T.start_year > 2000
# AND TR.num_votes > 100000
#
# GROUP BY N.name_id, N.name_
#
# HAVING COUNT(1) > 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 6 rows affected.
# [('Wes Anderson', 7.671428680419922),
#  ('Joel Coen', 6.900000015894572),
#  ('Ethan Coen', 6.900000015894572),
#  ('Adam McKay', 6.987499952316284),
#  ('Shawn Levy', 6.400000015894572),
#  ('Todd Phillips', 6.685714244842529)]

# %% [markdown]
# Using the IMDb database, retrieve the total number of movies and the average runtime of movies in each genre, but only for genres with more than 10 movies released after 2010. Group the results by genre and filter out any genres where the average runtime is less than 90 minutes.

# %%
# %%sql
#
# USE IMDb;
#
# SELECT TG.genre, COUNT(1) n , AVG(runtime_minutes) avg_runtime
# FROM Titles T
#
# JOIN Title_genres TG ON T.title_id = TG.title_id
#
# WHERE T.title_type = "movie"
# AND T.start_year > 2010
#
# GROUP BY TG.genre
#
# HAVING n>10
# AND avg_runtime >= 90
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 13 rows affected.
# [('Drama', 52137, Decimal('97.0928')),
#  ('Thriller', 12417, Decimal('94.8803')),
#  ('Comedy', 25649, Decimal('95.0057')),
#  ('Musical', 1405, Decimal('99.3310')),
#  ('Sci-Fi', 3449, Decimal('90.5526')),
#  ('Fantasy', 3909, Decimal('92.7493')),
#  ('Adventure', 6557, Decimal('91.0950')),
#  ('Mystery', 5251, Decimal('94.0764')),
#  ('Action', 10439, Decimal('101.4678')),
#  ('Romance', 9869, Decimal('101.0402')),
#  ('Crime', 7440, Decimal('98.0786')),
#  ('War', 1392, Decimal('91.9016')),
#  ('Western', 495, Decimal('90.3677'))]

# %%
# %%sql
#
# SELECT  CO.Name, CO.Continent, AVG(CT.Population) FROM city CT
# JOIN country CO ON CO.Code = CT.CountryCode
#
# WHERE CO.Population > 10000000
#
# GROUP BY CO.Continent,CT.CountryCode
# ORDER BY CO.Continent
# LIMIT 1
# Out:
#  * mysql+mysqlconnector://root:***@db
# 1 rows affected.
# [('Afghanistan', 'Asia', Decimal('583025.0000'))]

# %%
# %%sql
#
# SELECT CO.Name, CO.Region, SUM(1) n
# FROM country CO
#
# RIGHT JOIN countrylanguage CL ON CL.CountryCode = CO.Code
# WHERE CO.Continent = "Asia"
# AND CO.Population > 50000000
# GROUP BY CO.Region, CO.Code
# ORDER BY CO.Region
# Out:
#  * mysql+mysqlconnector://root:***@db
# 11 rows affected.
# [('China', 'Eastern Asia', Decimal('12')),
#  ('Japan', 'Eastern Asia', Decimal('6')),
#  ('Turkey', 'Middle East', Decimal('3')),
#  ('Indonesia', 'Southeast Asia', Decimal('9')),
#  ('Philippines', 'Southeast Asia', Decimal('10')),
#  ('Thailand', 'Southeast Asia', Decimal('6')),
#  ('Vietnam', 'Southeast Asia', Decimal('9')),
#  ('Bangladesh', 'Southern and Central Asia', Decimal('7')),
#  ('India', 'Southern and Central Asia', Decimal('12')),
#  ('Iran', 'Southern and Central Asia', Decimal('10')),
#  ('Pakistan', 'Southern and Central Asia', Decimal('8'))]

# %%
# %%sql
#
# USE IMDb;
# SELECT T.start_year year, AVG(TR.average_rating) avg_rating
# FROM Titles T
#
# JOIN Title_ratings TR ON TR.title_id = T.title_id
# JOIN Title_genres TG ON TG.title_id = T.title_id
# WHERE TG.genre = 'Action'
# AND T.title_type = 'movie'
# AND T.runtime_minutes > 90
#
# GROUP BY T.start_year
# ORDER BY T.start_year ASC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 33 rows affected.
# [(1990, 5.716287857655323),
#  (1991, 5.615217393377553),
#  (1992, 5.736018955990036),
#  (1993, 5.638362055194789),
#  (1994, 5.523886651645305),
#  (1995, 5.552845525547741),
#  (1996, 5.51945699394019),
#  (1997, 5.56964285671711),
#  (1998, 5.509389669122831),
#  (1999, 5.646255498415573),
#  (2000, 5.538709665773101),
#  (2001, 5.593680313528692),
#  (2002, 5.653090907877142),
#  (2003, 5.643083006025774),
#  (2004, 5.651890037805354),
#  (2005, 5.713207546270119),
#  (2006, 5.582638869269027),
#  (2007, 5.706953640805175),
#  (2008, 5.628260878672511),
#  (2009, 5.708943077865332),
#  (2010, 5.7056074805348835),
#  (2011, 5.785956414213481),
#  (2012, 5.769431274931578),
#  (2013, 5.7591703094249205),
#  (2014, 5.877575770773069),
#  (2015, 5.77131630723275),
#  (2016, 5.824697750014138),
#  (2017, 5.879126224317211),
#  (2018, 5.820934245743141),
#  (2019, 5.8132550322369445),
#  (2020, 5.692138360731257),
#  (2021, 6.1228365284892226),
#  (2022, 6.797368394701104)]

# %%
# %%sql
#
# SELECT N.name_ Name, COUNT(1) n
# FROM Names_ N
# LEFT JOIN Directors D ON D.name_id = N.name_id
# LEFT JOIN Had_role H ON H.name_id = N.name_id
# JOIN Titles T ON (T.title_id = D.title_id) OR (T.title_id = H.title_id)
# WHERE T.title_type = 'movie'
# GROUP BY N.name_id,N.name_
# ORDER BY n DESC
# LIMIT 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# (mysql.connector.errors.OperationalError) 2013 (HY000): Lost connection to MySQL server during query
# [SQL: SELECT N.name_ Name, COUNT(1) n
# FROM Names_ N
# LEFT JOIN Directors D ON D.name_id = N.name_id
# LEFT JOIN Had_role H ON H.name_id = N.name_id
# JOIN Titles T ON (T.title_id = D.title_id) OR (T.title_id = H.title_id)
# WHERE T.title_type = 'movie'
# GROUP BY N.name_id,N.name_
# ORDER BY n DESC
# LIMIT 5]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# USE IMDb;
# SELECT N.name_ dir_name, AVG(TR.average_rating) avg_rating
# FROM Titles T
#
# JOIN Title_genres TG ON TG.title_id = T.title_id
# JOIN Title_ratings TR ON TR.title_id = T.title_id
# JOIN Directors D ON D.title_id = T.title_id
# JOIN Names_ N ON D.name_id = N.name_id
#
# WHERE TG.genre = 'Comedy'
# AND T.title_type = 'movie'
# AND T.start_year > 2000
# AND TR.num_votes > 100000
#
# GROUP BY N.name_id,N.name_
# HAVING COUNT(D.title_id) > 5
# Out:
#  * mysql+mysqlconnector://root:***@db
# 0 rows affected.
# 6 rows affected.
# [('Wes Anderson', 7.671428680419922),
#  ('Joel Coen', 6.900000015894572),
#  ('Ethan Coen', 6.900000015894572),
#  ('Adam McKay', 6.987499952316284),
#  ('Shawn Levy', 6.400000015894572),
#  ('Todd Phillips', 6.685714244842529)]

# %%
# %%sql
#
# SELECT TG.genre, COUNT(1) n, AVG(T.runtime_minutes) avg_runtime
# FROM Titles T
# JOIN Title_genres TG ON TG.title_id = T.title_id
#
# WHERE T.title_type = 'movie'
# AND TG.genre IN (SELECT genre
# FROM Title_genres TG
# JOIN Titles T ON T.title_id = TG.title_id
# WHERE T.title_type = 'movie'
# AND T.start_year > 2010
# GROUP BY genre
# HAVING COUNT(1)>10
# )
# GROUP BY TG.genre
# HAVING AVG(T.runtime_minutes) > 90
# ORDER BY n DESC
# Out:
#  * mysql+mysqlconnector://root:***@db
# 13 rows affected.
# [('Drama', 92978, Decimal('98.5102')),
#  ('Comedy', 47279, Decimal('95.5126')),
#  ('Action', 20412, Decimal('102.8861')),
#  ('Thriller', 20402, Decimal('95.7721')),
#  ('Romance', 19590, Decimal('102.7264')),
#  ('Crime', 14584, Decimal('99.3953')),
#  ('Adventure', 10667, Decimal('92.6280')),
#  ('Mystery', 8430, Decimal('95.8456')),
#  ('Fantasy', 6848, Decimal('93.6633')),
#  ('Sci-Fi', 5649, Decimal('91.3730')),
#  ('War', 2848, Decimal('94.3079')),
#  ('Musical', 2530, Decimal('101.8684')),
#  ('Western', 805, Decimal('91.7255'))]

# %%
# %%sql
# SELECT genre,COUNT(1)
# FROM Title_genres TG
# JOIN Titles T ON T.title_id = TG.title_id
# WHERE T.title_type = 'movie'
# AND T.start_year > 2010
# GROUP BY genre
# HAVING COUNT(1)>10
# Out:
#  * mysql+mysqlconnector://root:***@db
# 24 rows affected.
# [('Drama', 52137),
#  ('Documentary', 48217),
#  ('Horror', 11186),
#  ('Music', 4370),
#  ('Thriller', 12417),
#  ('Comedy', 25649),
#  ('Musical', 1405),
#  ('Sci-Fi', 3449),
#  ('Fantasy', 3909),
#  ('Adventure', 6557),
#  ('Animation', 3168),
#  ('Biography', 7699),
#  ('History', 5623),
#  ('Mystery', 5251),
#  ('Action', 10439),
#  ('Romance', 9869),
#  ('Crime', 7440),
#  ('Family', 6000),
#  ('War', 1392),
#  ('Sport', 2640),
#  ('Western', 495),
#  ('News', 1041),
#  ('Short', 33),
#  ('Talk-Show', 56)]
